# %% [markdown]
# # Course Prerequisite Graph Builder
#
# **Author**: Lawrence Granda
# **Institution**: Cornell University
# **Email**: lg626@cornell.edu
# **Course**: ORIE 4999: First year course and education analytics team
# **Advisor**: Dr. David Alan Goldberg

# %% [markdown]
# **Project Title: Course Prerequisite Graph Builder**
#
# **Overview:**
# The Course Prerequisite Graph Builder is a tool designed to extract, organize, and visualize prerequisite relationships between courses offered by Cornell University. The project aims to create a structured graph representing the prerequisites required for different courses, facilitating better understanding and planning for students and academic advisors.
#
# **Features:**
# - **Course Information Extraction:** Utilizes web scraping techniques to extract course details such as department, course number, semesters offered, and prerequisites from university course rosters.
# - **Graph Construction:** Constructs a directed graph where nodes represent individual courses, and edges signify prerequisite relationships between courses.
# - **Visualization:** Provides a visual representation of the course graph, distinguishing courses based on the semesters they are offered.
# - **Filtered Course Lists:** Generates filtered course lists based on specified semesters and departments, aiding in the identification of relevant courses for academic planning.
#
# **Functionality:**
# - **Data Collection:** The system collects course information by parsing HTML content from university course roster web pages using web scraping libraries like BeautifulSoup.
# - **Graph Generation:** It utilizes extracted course information to build a graph structure representing the relationships between courses and their prerequisites.
# - **Filtered Course Lists:** Allows users to specify semesters and departments, providing filtered course lists meeting the specified criteria.
#
# **Purpose:**
# - **Student Planning:** Helps students plan their academic path by visualizing the prerequisites required for different courses, assisting in selecting suitable classes each semester.
# - **Advisor Assistance:** Supports academic advisors in guiding students by presenting clear prerequisite relationships, aiding in curriculum planning.
# - **Cornell University:** Provides a structured representation of course prerequisites for universities, assisting in curriculum development and review.
#
# **Technologies Used:**
# - Python
# - Requests library for HTTP requests
# - BeautifulSoup for web scraping
# - Regular Expressions (Regex)
# - Graph Visualization Tools ([Graphviz](https://edotor.net/?engine=dot?engine=dot?engine=dot?engine=dot?engine=dot?engine=dot#digraph%20G%20%7B%0Agraph%20%5Bpad%3D%220%22%2C%20nodesep%3D%220.15%22%2C%20ranksep%3D%221%22%5D%3B%0Aoverlap%20%3D%20false%3B%0Asplines%20%3D%20true%3B%0A%0A%22CS%201110%22%0A%22MATH%201910%22%20-%3E%20%22CS%201112%22%0A%22MATH%201110%22%20-%3E%20%22CS%201112%22%0A%22CS%202024%22%0A%22CS%201112%22%20-%3E%20%22CS%202110%22%0A%22CS%201110%22%20-%3E%20%22CS%202110%22%0A%22CS%201110%22%20-%3E%20%22CS%202112%22%0A%22CS%202800%22%0A%22CS%202800%22%20-%3E%20%22CS%203110%22%0A%22CS%202110%22%20-%3E%20%22CS%203110%22%0A%22CS%202024%22%20-%3E%20%22CS%203410%22%0A%22CS%202110%22%20-%3E%20%22CS%203410%22%0A%22ECE%202300%22%20-%3E%20%22CS%203420%22%0A%22ENGRD%202140%22%20-%3E%20%22CS%203420%22%0A%22ECE%202400%22%20-%3E%20%22CS%203420%22%0A%22ENGRD%202300%22%20-%3E%20%22CS%203420%22%0A%22CS%203420%22%20-%3E%20%22CS%204410%22%0A%22CS%203410%22%20-%3E%20%22CS%204410%22%0A%22ECE%202400%22%20-%3E%20%22CS%204414%22%0A%22CS%203410%22%20-%3E%20%22CS%204414%22%0A%22CS%202110%22%20-%3E%20%22CS%204414%22%0A%22CS%202800%22%20-%3E%20%22CS%204820%22%0A%22CS%203110%22%20-%3E%20%22CS%204820%22%0A%22CS%201112%22%20-%3E%20%22ECE%202300%22%0A%22CS%201110%22%20-%3E%20%22ECE%202300%22%0A%22CS%201112%22%20-%3E%20%22ECE%202400%22%0A%22CS%201110%22%20-%3E%20%22ECE%202400%22%0A%22CS%201112%22%20-%3E%20%22ENGRD%202140%22%0A%22CS%201110%22%20-%3E%20%22ENGRD%202140%22%0A%22CS%201112%22%20-%3E%20%22ENGRD%202300%22%0A%22CS%201110%22%20-%3E%20%22ENGRD%202300%22%0A%22MATH%201106%22%0A%22MATH%201110%22%0A%22MATH%201110%22%20-%3E%20%22MATH%201120%22%0A%22MATH%201106%22%20-%3E%20%22MATH%201120%22%0A%22MATH%201910%22%0A%22MATH%201910%22%20-%3E%20%22MATH%201920%22%0A%22MATH%201120%22%20-%3E%20%22MATH%202210%22%0A%22MATH%201110%22%20-%3E%20%22MATH%202210%22%0A%22MATH%201920%22%20-%3E%20%22MATH%202940%22%0A%7D))
#
# **Potential Enhancements:**
# - Interactive visualization for user interaction with the graph.
# - Integration with academic planning tools or student portals.
# - Incorporation of more sophisticated graph algorithms for deeper analysis.
# - Analysis of the graph to extract relevant information about prerequisite chains.

# %% [markdown]
# ## Course Information Extraction

# %% [markdown]
# ### Course Class:
# - **Purpose:** The `Course` class represents a single course. It extracts and stores information such as the department abbreviation, course number, semesters offered, and prerequisite courses.
# - **How it Works:**
#   - **Initialization:** When a `Course` object is created, it extracts the department abbreviation and course number from the given class name using regular expressions.
#   - **Extracting Information:** It then attempts to retrieve information about semesters when the course is offered and its prerequisites. It iterates through different years and semesters to find this information.
#   - **Logic:** It uses web requests to fetch the class information from Cornell's course roster. Upon obtaining the webpage content, it uses BeautifulSoup to parse the HTML content and extract semesters and prerequisites.

# %%
import requests
from bs4 import BeautifulSoup
import re
from collections import deque
from collections import OrderedDict


class Course:
    def __init__(self, class_name):
        """
        Initializes a Course object.

        Args:
        - class_name (str): Name of the class in the format 'DEPT XXXX'.

        Attributes:
        - class_name (str): Name of the class.
        - department (str): Extracted department abbreviation.
        - number (int): Extracted course number.
        - found (bool): Indicates if the class was found on the roster.
        - year (int): Year from which class information is retrieved.
        - semesters (set): Extracted set of semesters when the course is offered.
        - prerequisites (set): Extracted set of prerequisite courses.
        """
        self.class_name = class_name

        # Extract department abbreviation and course number from class name
        self.department = re.search(r'([A-Z]+)', class_name).group()
        self.number = int(re.search(r'([0-9]{4})', class_name).group())

        self.found = True  # Indicates if the class was found
        self.year = 23 # Default year

        self.semesters = self.extract_semesters()
        self.prerequisites = self.extract_prerequisites()


    def get_class_link(self, semester, year):
        """
        Constructs the URL for the class.

        Args:
        - semester (str): Semester code ('FA', 'SP', etc.).
        - year (int): Year for which the class information is requested.

        Returns:
        - response (Response object): HTTP response object.
        """
        link = f'https://classes.cornell.edu/browse/roster/{semester}{year}/class/{self.department}/{self.number}'
        return requests.get(link)


    def extract_prerequisites(self):
        """
        Extracts prerequisite courses for the class.

        Returns:
        - prerequisites_set (set): Set of prerequisite courses.
        """
        response = self.get_class_link('FA', self.year)

        # Attempting to retrieve class information for different semesters and years if not found initially
        if not response.ok:
            response = self.get_class_link('SP', self.year)
        if not response.ok:
            response = self.get_class_link('FA', self.year-1)
        if not response.ok:
            response = self.get_class_link('SP', self.year-1)
        if not response.ok:
            response = self.get_class_link('FA', self.year-2)
        if not response.ok:
            response = self.get_class_link('SP', self.year-2)

        if not response.ok:
            print(f"Class not found: {self.class_name}")
            return None # Return None if class information is not found

        # Parse the HTML content to extract prerequisites
        soup = BeautifulSoup(response.text, 'html.parser')
        prerequisites_set = set()

        # Extract prerequisite using regular expressions
        catalog_prereq_tag = soup.find('span', class_='catalog-prereq')
        if catalog_prereq_tag:
            text = catalog_prereq_tag.text.strip()
            prerequisites_text = text

            prerequisite_pattern = re.compile(r'(?:requisite[s]*:)\s*(.*?)[.]')
            matches = prerequisite_pattern.findall(prerequisites_text)

            for m in matches:
                course_pattern = re.compile(r'(?::\s*)*(?:\s+or\s*)*(?:\s+and\s*)*(?:\s*,\s*)*(?:\s*\.\s*)*([A-Z]+\s*[0-9]{4})')
                course_matches = course_pattern.findall(m)

                for course in course_matches:
                    prerequisites_set.add(course)

        return prerequisites_set


    def extract_semesters(self):
        """
        Extracts semesters during which the course is offered.

        Returns:
        - semesters (set): Set of semesters when the course is offered.
        """
        response = self.get_class_link('FA', self.year)

        # Attempting to retrieve class information for different semesters and years if not found initially
        if not response.ok:
            response = self.get_class_link('SP', self.year)
        if not response.ok:
            response = self.get_class_link('FA', self.year-1)
        if not response.ok:
            response = self.get_class_link('SP', self.year-1)
        if not response.ok:
            response = self.get_class_link('FA', self.year-2)
        if not response.ok:
            response = self.get_class_link('SP', self.year-2)

        if not response.ok:
            print(f"Class not found: {self.class_name}")
            return None # Return None if class information is not found

        # Parse the HTML content to extract semesters
        soup = BeautifulSoup(response.text, 'html.parser')
        semesters = set()

        # Extract semesters when the course is offered from the HTML content
        catalog_prereq_tag = soup.find('span', class_='catalog-when-offered')
        if catalog_prereq_tag:
            text = catalog_prereq_tag.text.strip().lower()

            if 'spring' in text:
                semesters.add('Spring')
            if 'fall' in text:
                semesters.add('Fall')
            if 'summer' in text:
                semesters.add('Summer')
            if 'winter' in text:
                semesters.add('Winter')

        return semesters

# %% [markdown]
# ## Graph Generation Algorithm

# %% [markdown]
# ### ClassNode and PrerequisiteGraph Classes:
# - **Purpose:** These classes work together to build a prerequisite graph representing relationships between courses and their prerequisites.
# - **How it Works:**
#   - **ClassNode:** Represents a node in the graph. Each node corresponds to a specific class and stores information about that class.
#   - **PrerequisiteGraph:** Manages the creation and traversal of the prerequisite graph using breadth-first search (BFS)-like behavior.
#   - **Building the Graph:** It constructs a graph of classes where nodes represent individual courses, and edges denote the prerequisite relationships between courses.
#   - **Traversal:** It employs BFS traversal to explore the prerequisites of courses, creating a directed graph structure where nodes represent classes, and edges indicate prerequisite relationships.
#   - **Printing Edges:** This function prints the edges of the prerequisite graph, considering the semesters in which the courses are offered. It generates a visual representation using specific node properties based on offered semesters.
#
# ### extract_courses and get_course_list Functions:
# - **Purpose:** These functions assist in collecting and filtering the list of courses available on the Cornell University website.
# - **How it Works:**
#   - **extract_courses:** Retrieves course names from the provided webpage by finding elements with a specific HTML class and parsing the content using BeautifulSoup.
#   - **get_course_list:** Gathers a filtered list of computer science course names based on specified semesters and department. It utilizes `extract_courses` to extract course names and then filters them based on the course number.

# %%
class ClassNode:
    def __init__(self, class_name):
        """
        Represents a class node in the prerequisite graph.

        Args:
        - class_name (str): Name of the class.

        Attributes:
        - course (Course): Instance of the Course class representing a class.
        - prerequisite_graph (set): Set of prerequisites for the class.
        """
        self.course = Course(class_name)
        self.prerequisite_graph = set()

    def get_prerequisites(self):
        """Retrieve the prerequisites of the class."""
        return self.course.prerequisites

    def get_name(self):
        """Retrieve the name of the class."""
        return self.course.class_name

    def get_semesters(self):
        """Retrieve the semesters when the class is offered."""
        return self.course.semesters


class PrerequisiteGraph:
    def __init__(self, course_list):
        """
        Represents a graph structure of class prerequisites.

        Args:
        - course_list (list): List of course names.

        Attributes:
        - graph (dict): Graph structure representing the relationship between classes.
        """
        self.graph = self.build_graph(course_list)

    def build_graph(self, course_list):
        """
        Builds the prerequisite graph from the list of courses.

        Args:
        - course_list (list): List of course names.

        Returns:
        - graph (dict): Graph structure representing the relationship between classes.
        """
        graph = {}  # Initialize an empty graph
        visited = set()  # Set to keep track of visited classes

        for course_name in course_list:
            self.build_prerequisite_graph(graph, course_name, visited)

        return graph


    def build_prerequisite_graph(self, graph, class_name, visited):
        """
        Builds the prerequisite graph for a given class.

        Args:
        - graph (dict): Graph structure representing the relationship between classes.
        - class_name (str): Name of the class.
        - visited (set): Set to keep track of visited classes.
        """
        assert type(class_name) == str
        assert type(graph) == dict
        assert type(visited) == set

        queue = deque([class_name])

        while queue:
            current_class = queue.popleft()

            if current_class in visited:
                # Skip processing if the class has already been visited
                continue

            # print(f"Building graph for {current_class}")

            visited.add(current_class)

            if current_class not in graph:
                graph[current_class] = ClassNode(current_class)

            prerequisites = graph[current_class].get_prerequisites()

            if prerequisites is None:
                # If prerequisites not found, mark the class as not found
                graph[current_class].found = False
            else:
                for prereq in prerequisites:
                    if prereq not in graph:
                        graph[prereq] = ClassNode(prereq)

                    # Establish the prerequisite relationship in the graph
                    graph[current_class].prerequisite_graph.add(graph[prereq])

                    queue.append(prereq)

        return graph

    def print_edges(self):
        """
        Prints the edges of the prerequisite graph with class node properties
        based on offered semesters.
        """
        # Sort the graph
        sorted_keys = list(self.graph.keys())
        sorted_keys.sort()
        sorted_graph = {key: self.graph[key] for key in sorted_keys}

        for class_name in sorted_graph:
            node = sorted_graph[class_name]

            if node.get_semesters() and "Spring" in node.get_semesters() and "Fall" in node.get_semesters():
                print(f"\"{node.get_name()}\" [fillcolor=gray, fontcolor=black, style=filled];")
            elif node.get_semesters() and "Fall" in node.get_semesters():
                print(f"\"{node.get_name()}\" [fillcolor=black, fontcolor=white, style=filled];")
            else:
                print(f"\"{node.get_name()}\" [fillcolor=white, fontcolor=black, style=filled];")

            if node.prerequisite_graph:
                for prerequisite in node.prerequisite_graph:
                    print(f"\"{prerequisite.get_name()}\" -> \"{node.get_name()}\";")



def extract_courses(link):
    """
    Extracts computer science course names from the provided webpage link.

    Args:
    - link (str): URL of the webpage to extract course names from.

    Returns:
    - courses (set): Set of computer science course names extracted from the webpage.
    """
    response = requests.get(link)
    soup = BeautifulSoup(response.text, 'html.parser')
    courses = set()

    # Extract computer science course names from the webpage
    course_name_elements = soup.find_all('div', class_='title-subjectcode')
    for element in course_name_elements:
        courses.add(element.text.strip())

    return courses

def get_course_list(semesters, department):
    """
    Generates a filtered list of computer science course names from Cornell University.

    Args:
    - semesters (list): List of strings representing semesters.
    - department (str): Department code for which course names are to be extracted.

    Returns:
    - course_list (list): Filtered list of computer science course names from Cornell University.
    """
    course_list = []

    for semester in semesters:
        # Extract computer science course names from Cornell
        courses = extract_courses(f'https://classes.cornell.edu/browse/roster/{semester}/subject/{department}')
        for course_name in courses:
            course_number = int(re.search(r'([0-9]{4})', course_name).group())
            if course_number < 5000:
                course_list.append(course_name)

    return course_list

# %% [markdown]
# ### Graph Generation

# %%
course_list = get_course_list(['FA23', 'SP23'], 'CS')
graph = PrerequisiteGraph(course_list)
graph.print_edges()
# Out:
# "AEP 3200" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2940" -> "AEP 3200";
# "MATH 2930" -> "AEP 3200";
# "AEP 3610" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 2214" -> "AEP 3610";
# "PHYS 2218" -> "AEP 3610";
# "AEP 4200" -> "AEP 3610";
# "AEP 4200" [fillcolor=black, fontcolor=white, style=filled];
# "AEP 3200" -> "AEP 4200";
# "BTRY 3010" [fillcolor=black, fontcolor=white, style=filled];
# "CS 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1112" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1910" -> "CS 1112";
# "MATH 1110" -> "CS 1112";
# "CS 1132" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1133" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1300" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1380" [fillcolor=white, fontcolor=black, style=filled];
# "CS 1620" [fillcolor=black, fontcolor=white, style=filled];
# "CS 1700" [fillcolor=white, fontcolor=black, style=filled];
# "CS 1710" [fillcolor=black, fontcolor=white, style=filled];
# "CS 1998" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 2024" [fillcolor=black, fontcolor=white, style=filled];
# "CS 2043" [fillcolor=white, fontcolor=black, style=filled];
# "CS 2110" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1112" -> "CS 2110";
# "CS 1110" -> "CS 2110";
# "CS 2300" [fillcolor=white, fontcolor=black, style=filled];
# "CS 1300" -> "CS 2300";
# "CS 2770" [fillcolor=white, fontcolor=black, style=filled];
# "CS 2800" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 2802" [fillcolor=black, fontcolor=white, style=filled];
# "CS 2850" [fillcolor=black, fontcolor=white, style=filled];
# "CS 3110" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 2110" -> "CS 3110";
# "CS 2800" -> "CS 3110";
# "CS 3152" [fillcolor=white, fontcolor=black, style=filled];
# "ENGRC 3152" -> "CS 3152";
# "CS 3220" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2940" -> "CS 3220";
# "MATH 2210" -> "CS 3220";
# "CS 3300" [fillcolor=black, fontcolor=white, style=filled];
# "CS 2110" -> "CS 3300";
# "ENGRD 2110" -> "CS 3300";
# "CS 3410" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 2110" -> "CS 3410";
# "CS 2024" -> "CS 3410";
# "CS 3420" [fillcolor=white, fontcolor=black, style=filled];
# "ENGRD 2300" -> "CS 3420";
# "ECE 2300" -> "CS 3420";
# "ECE 2400" -> "CS 3420";
# "ENGRD 2140" -> "CS 3420";
# "CS 4090" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 4120" [fillcolor=white, fontcolor=black, style=filled];
# "CS 3110" -> "CS 4120";
# "CS 3420" -> "CS 4120";
# "CS 4121" -> "CS 4120";
# "CS 3410" -> "CS 4120";
# "CS 4121" [fillcolor=white, fontcolor=black, style=filled];
# "CS 4120" -> "CS 4121";
# "CS 4152" [fillcolor=white, fontcolor=black, style=filled];
# "CS 5414" -> "CS 4152";
# "CS 4700" -> "CS 4152";
# "CS 3300" -> "CS 4152";
# "CS 3152" -> "CS 4152";
# "CS 4620" -> "CS 4152";
# "ENGRC 4152" -> "CS 4152";
# "CS 4210" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2240" -> "CS 4210";
# "MATH 2940" -> "CS 4210";
# "MATH 2230" -> "CS 4210";
# "MATH 2210" -> "CS 4210";
# "CS 4220" [fillcolor=white, fontcolor=black, style=filled];
# "CS 4210" -> "CS 4220";
# "MATH 2210" -> "CS 4220";
# "MATH 4250" -> "CS 4220";
# "MATH 2940" -> "CS 4220";
# "CS 3220" -> "CS 4220";
# "CS 4300" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2940" -> "CS 4300";
# "CS 2800" -> "CS 4300";
# "CS 4320" [fillcolor=black, fontcolor=white, style=filled];
# "CS 2110" -> "CS 4320";
# "CS 2800" -> "CS 4320";
# "CS 4321" [fillcolor=black, fontcolor=white, style=filled];
# "CS 5320" -> "CS 4321";
# "CS 4320" -> "CS 4321";
# "CS 4410" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 3420" -> "CS 4410";
# "CS 3410" -> "CS 4410";
# "CS 4411" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 4410" -> "CS 4411";
# "CS 4414" [fillcolor=white, fontcolor=black, style=filled];
# "CS 2110" -> "CS 4414";
# "ECE 2400" -> "CS 4414";
# "CS 3410" -> "CS 4414";
# "CS 4420" [fillcolor=black, fontcolor=white, style=filled];
# "ECE 3140" -> "CS 4420";
# "CS 3420" -> "CS 4420";
# "CS 3410" -> "CS 4420";
# "CS 4450" [fillcolor=black, fontcolor=white, style=filled];
# "CS 4410" -> "CS 4450";
# "CS 4620" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2210" -> "CS 4620";
# "MATH 2940" -> "CS 4620";
# "CS 2110" -> "CS 4620";
# "ENGRD 2110" -> "CS 4620";
# "CS 4621" [fillcolor=black, fontcolor=white, style=filled];
# "CS 4620" -> "CS 4621";
# "CS 4670" [fillcolor=white, fontcolor=black, style=filled];
# "CS 2110" -> "CS 4670";
# "CS 2800" -> "CS 4670";
# "CS 4700" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 2110" -> "CS 4700";
# "CS 2800" -> "CS 4700";
# "ENGRD 2110" -> "CS 4700";
# "CS 4701" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 4670" -> "CS 4701";
# "CS 4780" -> "CS 4701";
# "CS 4740" -> "CS 4701";
# "CS 4700" -> "CS 4701";
# "CS 4740" [fillcolor=black, fontcolor=white, style=filled];
# "CS 4744" [fillcolor=white, fontcolor=black, style=filled];
# "CS 2800" -> "CS 4744";
# "LING 1101" -> "CS 4744";
# "CS 1133" -> "CS 4744";
# "PHIL 2310" -> "CS 4744";
# "CS 4745" [fillcolor=black, fontcolor=white, style=filled];
# "LING 4424" -> "CS 4745";
# "CS 4750" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 4710" -> "CS 4750";
# "MATH 2210" -> "CS 4750";
# "MATH 2940" -> "CS 4750";
# "CS 1133" -> "CS 4750";
# "CS 1110" -> "CS 4750";
# "ENGRD 2700" -> "CS 4750";
# "MATH 1920" -> "CS 4750";
# "CS 4756" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2220" -> "CS 4756";
# "MATH 2940" -> "CS 4756";
# "CS 1110" -> "CS 4756";
# "CS 4780" -> "CS 4756";
# "MATH 1920" -> "CS 4756";
# "CS 4758" [fillcolor=white, fontcolor=black, style=filled];
# "CS 4775" [fillcolor=black, fontcolor=white, style=filled];
# "CS 2110" -> "CS 4775";
# "BTRY 3010" -> "CS 4775";
# "CS 4780" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 2800" -> "CS 4780";
# "CS 4783" [fillcolor=white, fontcolor=black, style=filled];
# "CS 4780" -> "CS 4783";
# "CS 4820" -> "CS 4783";
# "CS 4787" [fillcolor=black, fontcolor=white, style=filled];
# "CS 4780" -> "CS 4787";
# "CS 2110" -> "CS 4787";
# "CS 5780" -> "CS 4787";
# "CS 4789" [fillcolor=white, fontcolor=black, style=filled];
# "CS 4780" -> "CS 4789";
# "CS 4812" [fillcolor=black, fontcolor=white, style=filled];
# "AEP 3610" -> "CS 4812";
# "PHYS 3316" -> "CS 4812";
# "CS 4820" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 3110" -> "CS 4820";
# "CS 2800" -> "CS 4820";
# "CS 4830" [fillcolor=white, fontcolor=black, style=filled];
# "CS 4820" -> "CS 4830";
# "CS 4852" [fillcolor=white, fontcolor=black, style=filled];
# "INFO 2040" -> "CS 4852";
# "CS 2800" -> "CS 4852";
# "CS 4860" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2940" -> "CS 4860";
# "MATH 2230" -> "CS 4860";
# "MATH 2210" -> "CS 4860";
# "CS 4997" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 4998" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 4999" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 5320" [fillcolor=black, fontcolor=white, style=filled];
# "CS 2110" -> "CS 5320";
# "CS 2800" -> "CS 5320";
# "CS 5414" [fillcolor=white, fontcolor=black, style=filled];
# "CS 4410" -> "CS 5414";
# "CS 5780" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 2800" -> "CS 5780";
# "ECE 2300" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1112" -> "ECE 2300";
# "CS 1110" -> "ECE 2300";
# "ECE 2400" [fillcolor=black, fontcolor=white, style=filled];
# "CS 1112" -> "ECE 2400";
# "CS 1110" -> "ECE 2400";
# "ECE 3140" [fillcolor=white, fontcolor=black, style=filled];
# "ENGRD 2300" -> "ECE 3140";
# "ECE 2300" -> "ECE 3140";
# "ECE 2400" -> "ECE 3140";
# "ENGRD 2140" -> "ECE 3140";
# "ENGRC 3152" [fillcolor=white, fontcolor=black, style=filled];
# "CS 3152" -> "ENGRC 3152";
# "INFO 3152" -> "ENGRC 3152";
# "ENGRC 4152" [fillcolor=white, fontcolor=black, style=filled];
# "CS 4152" -> "ENGRC 4152";
# "INFO 4152" -> "ENGRC 4152";
# "ENGRD 2110" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1110" -> "ENGRD 2110";
# "ENGRD 2140" [fillcolor=black, fontcolor=white, style=filled];
# "CS 1112" -> "ENGRD 2140";
# "CS 1110" -> "ENGRD 2140";
# "ENGRD 2300" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1112" -> "ENGRD 2300";
# "CS 1110" -> "ENGRD 2300";
# "ENGRD 2700" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1910" -> "ENGRD 2700";
# "MATH 1920" -> "ENGRD 2700";
# "INFO 2040" [fillcolor=black, fontcolor=white, style=filled];
# "INFO 3152" [fillcolor=white, fontcolor=black, style=filled];
# "ENGRC 3152" -> "INFO 3152";
# "INFO 4152" [fillcolor=white, fontcolor=black, style=filled];
# "ENGRC 4152" -> "INFO 4152";
# "LING 1101" [fillcolor=gray, fontcolor=black, style=filled];
# "LING 4424" [fillcolor=white, fontcolor=black, style=filled];
# "CS 2800" -> "LING 4424";
# "LING 1101" -> "LING 4424";
# "CS 1133" -> "LING 4424";
# "PHIL 2310" -> "LING 4424";
# "MATH 1106" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1110" -> "MATH 1120";
# "MATH 1106" -> "MATH 1120";
# "MATH 1910" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1910" -> "MATH 1920";
# "MATH 2130" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1910" -> "MATH 2130";
# "MATH 1120" -> "MATH 2130";
# "MATH 2210" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" -> "MATH 2210";
# "MATH 1110" -> "MATH 2210";
# "MATH 2220" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2210" -> "MATH 2220";
# "MATH 2230" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1120" -> "MATH 2230";
# "MATH 1110" -> "MATH 2230";
# "MATH 2240" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2230" -> "MATH 2240";
# "MATH 2930" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "MATH 2930";
# "MATH 2940" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "MATH 2940";
# "MATH 4250" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2240" -> "MATH 4250";
# "MATH 2940" -> "MATH 4250";
# "MATH 2230" -> "MATH 4250";
# "MATH 2210" -> "MATH 4250";
# "MATH 4710" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" -> "MATH 4710";
# "MATH 1110" -> "MATH 4710";
# "PHIL 2310" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1101" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 2213" -> "PHYS 1110";
# "PHYS 1116" -> "PHYS 1110";
# "PHYS 1112" -> "PHYS 1110";
# "PHYS 2217" -> "PHYS 1110";
# "PHYS 1112" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1110" -> "PHYS 1112";
# "MATH 1910" -> "PHYS 1112";
# "PHYS 2213" -> "PHYS 1112";
# "MATH 1120" -> "PHYS 1112";
# "PHYS 1112" -> "PHYS 1112";
# "MATH 1920" -> "PHYS 1112";
# "PHYS 1116" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1110" -> "PHYS 1116";
# "MATH 1910" -> "PHYS 1116";
# "PHYS 1116" -> "PHYS 1116";
# "MATH 1120" -> "PHYS 1116";
# "PHYS 2207" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1110" -> "PHYS 2207";
# "MATH 1106" -> "PHYS 2207";
# "PHYS 2208" [fillcolor=white, fontcolor=black, style=filled];
# "PHYS 2207" -> "PHYS 2208";
# "PHYS 1112" -> "PHYS 2208";
# "PHYS 1101" -> "PHYS 2208";
# "PHYS 2210" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 2218" -> "PHYS 2210";
# "PHYS 2213" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2240" -> "PHYS 2213";
# "MATH 2220" -> "PHYS 2213";
# "PHYS 2207" -> "PHYS 2213";
# "PHYS 1112" -> "PHYS 2213";
# "MATH 1920" -> "PHYS 2213";
# "PHYS 2214" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2240" -> "PHYS 2214";
# "MATH 2130" -> "PHYS 2214";
# "MATH 2220" -> "PHYS 2214";
# "PHYS 2208" -> "PHYS 2214";
# "PHYS 2213" -> "PHYS 2214";
# "MATH 1920" -> "PHYS 2214";
# "PHYS 2216" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 2207" -> "PHYS 2216";
# "PHYS 1112" -> "PHYS 2216";
# "PHYS 2217" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2240" -> "PHYS 2217";
# "MATH 2220" -> "PHYS 2217";
# "PHYS 1116" -> "PHYS 2217";
# "PHYS 1112" -> "PHYS 2217";
# "MATH 1920" -> "PHYS 2217";
# "PHYS 2218" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 2210" -> "PHYS 2218";
# "PHYS 2213" -> "PHYS 2218";
# "PHYS 2218" -> "PHYS 2218";
# "PHYS 2217" -> "PHYS 2218";
# "PHYS 3316" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 2216" -> "PHYS 3316";
# "PHYS 2218" -> "PHYS 3316";
# "MATH 2210" -> "PHYS 3316";
# "MATH 2940" -> "PHYS 3316";
# "MATH 2230" -> "PHYS 3316";
# "PHYS 2214" -> "PHYS 3316";
# "PHYS 1116" -> "PHYS 3316";

# %%
course_list = get_course_list(['FA23', 'SP23'], 'AEP')
graph = PrerequisiteGraph(course_list)
graph.print_edges()
# Out:
# "AEP 1100" [fillcolor=gray, fontcolor=black, style=filled];
# "AEP 1200" [fillcolor=black, fontcolor=white, style=filled];
# "AEP 2170" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1116" -> "AEP 2170";
# "PHYS 1112" -> "AEP 2170";
# "AEP 2550" [fillcolor=white, fontcolor=black, style=filled];
# "PHYS 2213" -> "AEP 2550";
# "PHYS 1112" -> "AEP 2550";
# "MATH 2930" -> "AEP 2550";
# "PHYS 2217" -> "AEP 2550";
# "PHYS 1116" -> "AEP 2550";
# "MATH 1920" -> "AEP 2550";
# "AEP 3100" [fillcolor=white, fontcolor=black, style=filled];
# "CS 1110" -> "AEP 3100";
# "MATH 2940" -> "AEP 3100";
# "AEP 3200" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2930" -> "AEP 3200";
# "MATH 2940" -> "AEP 3200";
# "AEP 3330" [fillcolor=black, fontcolor=white, style=filled];
# "AEP 4200" -> "AEP 3330";
# "PHYS 1116" -> "AEP 3330";
# "PHYS 1112" -> "AEP 3330";
# "AEP 3550" [fillcolor=white, fontcolor=black, style=filled];
# "AEP 4200" -> "AEP 3550";
# "PHYS 2213" -> "AEP 3550";
# "PHYS 2217" -> "AEP 3550";
# "AEP 3560" [fillcolor=black, fontcolor=white, style=filled];
# "AEP 4200" -> "AEP 3560";
# "AEP 3550" -> "AEP 3560";
# "AEP 3610" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 2214" -> "AEP 3610";
# "AEP 4200" -> "AEP 3610";
# "PHYS 2218" -> "AEP 3610";
# "AEP 3620" [fillcolor=white, fontcolor=black, style=filled];
# "PHYS 3316" -> "AEP 3620";
# "AEP 4200" -> "AEP 3620";
# "AEP 3610" -> "AEP 3620";
# "AEP 3630" [fillcolor=gray, fontcolor=black, style=filled];
# "AEP 4130" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 2214" -> "AEP 4130";
# "MATH 2940" -> "AEP 4130";
# "AEP 4200" [fillcolor=black, fontcolor=white, style=filled];
# "AEP 3200" -> "AEP 4200";
# "AEP 4230" [fillcolor=black, fontcolor=white, style=filled];
# "AEP 4200" -> "AEP 4230";
# "AEP 3200" -> "AEP 4230";
# "AEP 3610" -> "AEP 4230";
# "AEP 3550" -> "AEP 4230";
# "AEP 4340" [fillcolor=white, fontcolor=black, style=filled];
# "AEP 4200" -> "AEP 4340";
# "AEP 3330" -> "AEP 4340";
# "AEP 3550" -> "AEP 4340";
# "AEP 4380" [fillcolor=black, fontcolor=white, style=filled];
# "AEP 3200" -> "AEP 4380";
# "AEP 3330" -> "AEP 4380";
# "CS 1110" -> "AEP 4380";
# "AEP 4200" -> "AEP 4380";
# "CS 1112" -> "AEP 4380";
# "PHYS 2214" -> "AEP 4380";
# "PHYS 2218" -> "AEP 4380";
# "AEP 3610" -> "AEP 4380";
# "AEP 4400" [fillcolor=white, fontcolor=black, style=filled];
# "AEP 3560" -> "AEP 4400";
# "AEP 3620" -> "AEP 4400";
# "AEP 4450" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 3030" -> "AEP 4450";
# "AEP 3550" -> "AEP 4450";
# "AEP 4500" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 4443" -> "AEP 4500";
# "CHEM 7930" -> "AEP 4500";
# "AEP 3610" -> "AEP 4500";
# "AEP 4812" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 3316" -> "AEP 4812";
# "AEP 3610" -> "AEP 4812";
# "AEP 4840" [fillcolor=white, fontcolor=black, style=filled];
# "PHYS 2213" -> "AEP 4840";
# "PHYS 2214" -> "AEP 4840";
# "PHYS 1112" -> "AEP 4840";
# "AEP 4900" [fillcolor=gray, fontcolor=black, style=filled];
# "AEP 4910" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 2070" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 2080" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 2070" -> "CHEM 2080";
# "CHEM 2090" -> "CHEM 2080";
# "CHEM 2090" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 3890" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 2208" -> "CHEM 3890";
# "CHEM 2080" -> "CHEM 3890";
# "MATH 2310" -> "CHEM 3890";
# "MATH 2130" -> "CHEM 3890";
# "MATH 2220" -> "CHEM 3890";
# "CHEM 7870" [fillcolor=black, fontcolor=white, style=filled];
# "CHEM 7930" [fillcolor=black, fontcolor=white, style=filled];
# "CHEM 3890" -> "CHEM 7930";
# "CHEM 7870" -> "CHEM 7930";
# "CS 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1112" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1110" -> "CS 1112";
# "MATH 1910" -> "CS 1112";
# "ECE 2100" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2930" -> "ECE 2100";
# "PHYS 2213" -> "ECE 2100";
# "MATH 1920" -> "ECE 2100";
# "PHYS 1112" -> "ECE 2100";
# "ECE 3030" [fillcolor=black, fontcolor=white, style=filled];
# "ECE 2100" -> "ECE 3030";
# "MATH 2930" -> "ECE 3030";
# "ENGRD 2100" -> "ECE 3030";
# "PHYS 2213" -> "ECE 3030";
# "ENGRD 2100" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2930" -> "ENGRD 2100";
# "PHYS 2213" -> "ENGRD 2100";
# "MATH 1920" -> "ENGRD 2100";
# "PHYS 1112" -> "ENGRD 2100";
# "MATH 1106" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1110" -> "MATH 1120";
# "MATH 1106" -> "MATH 1120";
# "MATH 1910" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1910" -> "MATH 1920";
# "MATH 2130" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1910" -> "MATH 2130";
# "MATH 1120" -> "MATH 2130";
# "MATH 2210" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1110" -> "MATH 2210";
# "MATH 1120" -> "MATH 2210";
# "MATH 2220" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2210" -> "MATH 2220";
# "MATH 2230" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1110" -> "MATH 2230";
# "MATH 1120" -> "MATH 2230";
# "MATH 2240" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2230" -> "MATH 2240";
# "MATH 2310" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1110" -> "MATH 2310";
# "MATH 1106" -> "MATH 2310";
# "MATH 2930" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "MATH 2930";
# "MATH 2940" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "MATH 2940";
# "PHYS 1101" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1116" -> "PHYS 1110";
# "PHYS 2213" -> "PHYS 1110";
# "PHYS 2217" -> "PHYS 1110";
# "PHYS 1112" -> "PHYS 1110";
# "PHYS 1112" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1910" -> "PHYS 1112";
# "PHYS 2213" -> "PHYS 1112";
# "PHYS 1112" -> "PHYS 1112";
# "PHYS 1110" -> "PHYS 1112";
# "MATH 1120" -> "PHYS 1112";
# "MATH 1920" -> "PHYS 1112";
# "PHYS 1116" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1116" -> "PHYS 1116";
# "MATH 1120" -> "PHYS 1116";
# "PHYS 1110" -> "PHYS 1116";
# "MATH 1910" -> "PHYS 1116";
# "PHYS 2207" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1110" -> "PHYS 2207";
# "MATH 1106" -> "PHYS 2207";
# "PHYS 2208" [fillcolor=white, fontcolor=black, style=filled];
# "PHYS 1101" -> "PHYS 2208";
# "PHYS 2207" -> "PHYS 2208";
# "PHYS 1112" -> "PHYS 2208";
# "PHYS 2210" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 2218" -> "PHYS 2210";
# "PHYS 2213" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1112" -> "PHYS 2213";
# "PHYS 2207" -> "PHYS 2213";
# "MATH 2220" -> "PHYS 2213";
# "MATH 1920" -> "PHYS 2213";
# "MATH 2240" -> "PHYS 2213";
# "PHYS 2214" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 2213" -> "PHYS 2214";
# "PHYS 2208" -> "PHYS 2214";
# "MATH 2130" -> "PHYS 2214";
# "MATH 2220" -> "PHYS 2214";
# "MATH 1920" -> "PHYS 2214";
# "MATH 2240" -> "PHYS 2214";
# "PHYS 2216" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 2207" -> "PHYS 2216";
# "PHYS 1112" -> "PHYS 2216";
# "PHYS 2217" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1112" -> "PHYS 2217";
# "PHYS 1116" -> "PHYS 2217";
# "MATH 2220" -> "PHYS 2217";
# "MATH 1920" -> "PHYS 2217";
# "MATH 2240" -> "PHYS 2217";
# "PHYS 2218" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 2210" -> "PHYS 2218";
# "PHYS 2217" -> "PHYS 2218";
# "PHYS 2213" -> "PHYS 2218";
# "PHYS 2218" -> "PHYS 2218";
# "PHYS 3316" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2940" -> "PHYS 3316";
# "PHYS 2216" -> "PHYS 3316";
# "MATH 2230" -> "PHYS 3316";
# "MATH 2210" -> "PHYS 3316";
# "PHYS 1116" -> "PHYS 3316";
# "PHYS 2214" -> "PHYS 3316";
# "PHYS 2218" -> "PHYS 3316";
# "PHYS 3317" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 3316" -> "PHYS 3317";
# "PHYS 3318" [fillcolor=white, fontcolor=black, style=filled];
# "PHYS 3327" [fillcolor=black, fontcolor=white, style=filled];
# "AEP 3200" -> "PHYS 3327";
# "PHYS 2213" -> "PHYS 3327";
# "AEP 4200" -> "PHYS 3327";
# "PHYS 2217" -> "PHYS 3327";
# "PHYS 2214" -> "PHYS 3327";
# "PHYS 2218" -> "PHYS 3327";
# "PHYS 4443" [fillcolor=white, fontcolor=black, style=filled];
# "PHYS 3327" -> "PHYS 4443";
# "PHYS 3316" -> "PHYS 4443";
# "PHYS 3317" -> "PHYS 4443";
# "PHYS 3318" -> "PHYS 4443";

# %%
course_list = get_course_list(['FA23', 'SP23'], 'BEE')
graph = PrerequisiteGraph(course_list)
graph.print_edges()
# Out:
# "BEE 2000" [fillcolor=white, fontcolor=black, style=filled];
# "BEE 2220" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1920" -> "BEE 2220";
# "PHYS 2213" -> "BEE 2220";
# "BEE 2510" [fillcolor=black, fontcolor=white, style=filled];
# "CHEM 2070" -> "BEE 2510";
# "CHEM 2090" -> "BEE 2510";
# "MATH 2930" -> "BEE 2510";
# "BEE 2600" [fillcolor=black, fontcolor=white, style=filled];
# "BIOG 1445" -> "BEE 2600";
# "MATH 2930" -> "BEE 2600";
# "BEE 3280" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2940" -> "BEE 3280";
# "BIOG 1440" -> "BEE 3280";
# "MATH 2930" -> "BEE 3280";
# "BEE 3600" -> "BEE 3280";
# "BIOMG 3300" -> "BEE 3280";
# "BEE 2600" -> "BEE 3280";
# "BEE 3299" [fillcolor=white, fontcolor=black, style=filled];
# "BEE 3310" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1920" -> "BEE 3310";
# "MATH 1910" -> "BEE 3310";
# "MATH 2930" -> "BEE 3310";
# "ENGRD 2020" -> "BEE 3310";
# "BEE 3400" [fillcolor=white, fontcolor=black, style=filled];
# "BEE 2220" -> "BEE 3400";
# "BEE 3500" -> "BEE 3400";
# "BEE 3500" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2930" -> "BEE 3500";
# "BEE 3600" [fillcolor=white, fontcolor=black, style=filled];
# "BEE 2600" -> "BEE 3600";
# "BEE 3710" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1920" -> "BEE 3710";
# "BEE 3801" [fillcolor=white, fontcolor=black, style=filled];
# "BEE 3900" [fillcolor=black, fontcolor=white, style=filled];
# "BEE 2600" -> "BEE 3900";
# "MATH 2930" -> "BEE 3900";
# "BEE 3910" [fillcolor=white, fontcolor=black, style=filled];
# "BEE 3900" -> "BEE 3910";
# "BEE 4270" [fillcolor=black, fontcolor=white, style=filled];
# "BEE 4500" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2940" -> "BEE 4500";
# "BEE 4530" [fillcolor=white, fontcolor=black, style=filled];
# "BEE 3500" -> "BEE 4530";
# "MAE 3240" -> "BEE 4530";
# "CHEME 3240" -> "BEE 4530";
# "BEE 4560" [fillcolor=black, fontcolor=white, style=filled];
# "BEE 3400" -> "BEE 4560";
# "BEE 3500" -> "BEE 4560";
# "ENGRD 2020" -> "BEE 4560";
# "BEE 3310" -> "BEE 4560";
# "BEE 4590" [fillcolor=black, fontcolor=white, style=filled];
# "ENGRC 4590" -> "BEE 4590";
# "BEE 4630" [fillcolor=white, fontcolor=black, style=filled];
# "BEE 4710" [fillcolor=white, fontcolor=black, style=filled];
# "BEE 4730" [fillcolor=black, fontcolor=white, style=filled];
# "CEE 3310" -> "BEE 4730";
# "BEE 4750" [fillcolor=black, fontcolor=white, style=filled];
# "BEE 2510" -> "BEE 4750";
# "BEE 2600" -> "BEE 4750";
# "BEE 4880" [fillcolor=white, fontcolor=black, style=filled];
# "BEE 4940" [fillcolor=gray, fontcolor=black, style=filled];
# "BEE 4970" [fillcolor=gray, fontcolor=black, style=filled];
# "BEE 4980" [fillcolor=gray, fontcolor=black, style=filled];
# "BEE 4990" [fillcolor=gray, fontcolor=black, style=filled];
# "BEE 4993" [fillcolor=gray, fontcolor=black, style=filled];
# "BEE 4990" -> "BEE 4993";
# "BEE 4994" [fillcolor=gray, fontcolor=black, style=filled];
# "BIOG 1440" [fillcolor=gray, fontcolor=black, style=filled];
# "BIOG 1445" [fillcolor=gray, fontcolor=black, style=filled];
# "BIOMG 3300" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 3530" -> "BIOMG 3300";
# "CHEM 1570" -> "BIOMG 3300";
# "BIOMG 3340" -> "BIOMG 3300";
# "CHEM 3570" -> "BIOMG 3300";
# "CHEM 3590" -> "BIOMG 3300";
# "BIOMG 3310" [fillcolor=black, fontcolor=white, style=filled];
# "CHEM 1570" -> "BIOMG 3310";
# "CHEM 3570" -> "BIOMG 3310";
# "CHEM 3590" -> "BIOMG 3310";
# "CHEM 3530" -> "BIOMG 3310";
# "BIOMG 3320" [fillcolor=white, fontcolor=black, style=filled];
# "BIOMG 3340" [fillcolor=gray, fontcolor=black, style=filled];
# "BIOMG 3300" -> "BIOMG 3340";
# "BIOMG 3320" -> "BIOMG 3340";
# "BIOMG 3350" -> "BIOMG 3340";
# "BIOMG 3310" -> "BIOMG 3340";
# "BIOMG 3350" [fillcolor=white, fontcolor=black, style=filled];
# "CHEM 1570" -> "BIOMG 3350";
# "CHEM 3570" -> "BIOMG 3350";
# "CHEM 3590" -> "BIOMG 3350";
# "CHEM 3530" -> "BIOMG 3350";
# "CEE 3310" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2930" -> "CEE 3310";
# "CHEM 1560" [fillcolor=black, fontcolor=white, style=filled];
# "CHEM 1570" [fillcolor=white, fontcolor=black, style=filled];
# "CHEM 2070" -> "CHEM 1570";
# "CHEM 1560" -> "CHEM 1570";
# "CHEM 2070" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 2080" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 2070" -> "CHEM 2080";
# "CHEM 2090" -> "CHEM 2080";
# "CHEM 2090" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 2150" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1910" -> "CHEM 2150";
# "MATH 1110" -> "CHEM 2150";
# "CHEM 2510" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 1570" -> "CHEM 2510";
# "CHEM 3570" -> "CHEM 2510";
# "CHEM 3590" -> "CHEM 2510";
# "CHEM 3530" -> "CHEM 2510";
# "CHEM 3530" [fillcolor=black, fontcolor=white, style=filled];
# "CHEM 2090" -> "CHEM 3530";
# "CHEM 2080" -> "CHEM 3530";
# "CHEM 3570" [fillcolor=black, fontcolor=white, style=filled];
# "CHEM 2080" -> "CHEM 3570";
# "CHEM 2510" -> "CHEM 3570";
# "CHEM 3590" [fillcolor=white, fontcolor=black, style=filled];
# "CHEM 2080" -> "CHEM 3590";
# "CHEM 2150" -> "CHEM 3590";
# "CHEME 3230" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2930" -> "CHEME 3230";
# "ENGRD 2190" -> "CHEME 3230";
# "CHEME 3240" [fillcolor=black, fontcolor=white, style=filled];
# "CHEME 3230" -> "CHEME 3240";
# "ENGRC 4590" [fillcolor=black, fontcolor=white, style=filled];
# "BEE 4590" -> "ENGRC 4590";
# "ENGRD 2020" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "ENGRD 2020";
# "PHYS 1112" -> "ENGRD 2020";
# "ENGRD 2190" [fillcolor=black, fontcolor=white, style=filled];
# "ENGRD 2210" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1920" -> "ENGRD 2210";
# "PHYS 1112" -> "ENGRD 2210";
# "MAE 2030" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2940" -> "MAE 2030";
# "MATH 2930" -> "MAE 2030";
# "ENGRD 2020" -> "MAE 2030";
# "MAE 3230" [fillcolor=black, fontcolor=white, style=filled];
# "ENGRD 2210" -> "MAE 3230";
# "MAE 2030" -> "MAE 3230";
# "ENGRD 2020" -> "MAE 3230";
# "MAE 3240" [fillcolor=white, fontcolor=black, style=filled];
# "MAE 3230" -> "MAE 3240";
# "MATH 1106" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1106" -> "MATH 1120";
# "MATH 1110" -> "MATH 1120";
# "MATH 1910" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1910" -> "MATH 1920";
# "MATH 2210" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1110" -> "MATH 2210";
# "MATH 1120" -> "MATH 2210";
# "MATH 2220" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2210" -> "MATH 2220";
# "MATH 2230" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1110" -> "MATH 2230";
# "MATH 1120" -> "MATH 2230";
# "MATH 2240" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2230" -> "MATH 2240";
# "MATH 2930" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "MATH 2930";
# "MATH 2940" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "MATH 2940";
# "PHYS 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1116" -> "PHYS 1110";
# "PHYS 2213" -> "PHYS 1110";
# "PHYS 1112" -> "PHYS 1110";
# "PHYS 2217" -> "PHYS 1110";
# "PHYS 1112" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 2213" -> "PHYS 1112";
# "MATH 1910" -> "PHYS 1112";
# "MATH 1920" -> "PHYS 1112";
# "PHYS 1112" -> "PHYS 1112";
# "PHYS 1110" -> "PHYS 1112";
# "MATH 1120" -> "PHYS 1112";
# "PHYS 1116" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1116" -> "PHYS 1116";
# "MATH 1910" -> "PHYS 1116";
# "PHYS 1110" -> "PHYS 1116";
# "MATH 1120" -> "PHYS 1116";
# "PHYS 2207" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1106" -> "PHYS 2207";
# "MATH 1110" -> "PHYS 2207";
# "PHYS 2213" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2240" -> "PHYS 2213";
# "MATH 1920" -> "PHYS 2213";
# "MATH 2220" -> "PHYS 2213";
# "PHYS 2207" -> "PHYS 2213";
# "PHYS 1112" -> "PHYS 2213";
# "PHYS 2217" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2240" -> "PHYS 2217";
# "MATH 1920" -> "PHYS 2217";
# "MATH 2220" -> "PHYS 2217";
# "PHYS 1116" -> "PHYS 2217";
# "PHYS 1112" -> "PHYS 2217";

# %%
course_list = get_course_list(['FA23', 'SP23'], 'BME')
graph = PrerequisiteGraph(course_list)
graph.print_edges()
# Out:
# "BIOG 1440" [fillcolor=gray, fontcolor=black, style=filled];
# "BIOG 1445" [fillcolor=gray, fontcolor=black, style=filled];
# "BIOG 1500" [fillcolor=gray, fontcolor=black, style=filled];
# "BIOMG 1350" [fillcolor=gray, fontcolor=black, style=filled];
# "BIOMG 3300" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 3530" -> "BIOMG 3300";
# "CHEM 3570" -> "BIOMG 3300";
# "CHEM 1570" -> "BIOMG 3300";
# "BIOMG 3340" -> "BIOMG 3300";
# "CHEM 3590" -> "BIOMG 3300";
# "BIOMG 3310" [fillcolor=black, fontcolor=white, style=filled];
# "CHEM 3530" -> "BIOMG 3310";
# "CHEM 3590" -> "BIOMG 3310";
# "CHEM 3570" -> "BIOMG 3310";
# "CHEM 1570" -> "BIOMG 3310";
# "BIOMG 3320" [fillcolor=white, fontcolor=black, style=filled];
# "BIOMG 3340" [fillcolor=gray, fontcolor=black, style=filled];
# "BIOMG 3310" -> "BIOMG 3340";
# "BIOMG 3300" -> "BIOMG 3340";
# "BIOMG 3350" -> "BIOMG 3340";
# "BIOMG 3320" -> "BIOMG 3340";
# "BIOMG 3350" [fillcolor=white, fontcolor=black, style=filled];
# "CHEM 3530" -> "BIOMG 3350";
# "CHEM 3590" -> "BIOMG 3350";
# "CHEM 3570" -> "BIOMG 3350";
# "CHEM 1570" -> "BIOMG 3350";
# "BIONB 2220" [fillcolor=white, fontcolor=black, style=filled];
# "BME 1310" [fillcolor=black, fontcolor=white, style=filled];
# "BME 2000" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2930" -> "BME 2000";
# "BME 2010" [fillcolor=white, fontcolor=black, style=filled];
# "BIOMG 1350" -> "BME 2010";
# "CHEM 2090" -> "BME 2010";
# "BME 2080" [fillcolor=white, fontcolor=black, style=filled];
# "BME 2081" [fillcolor=black, fontcolor=white, style=filled];
# "BME 2080" -> "BME 2081";
# "BME 2110" [fillcolor=white, fontcolor=black, style=filled];
# "BIOMG 1350" -> "BME 2110";
# "BME 2000" -> "BME 2110";
# "BIOG 1440" -> "BME 2110";
# "CHEM 2090" -> "BME 2110";
# "MATH 2930" -> "BME 2110";
# "ENGRD 2202" -> "BME 2110";
# "BME 2210" [fillcolor=black, fontcolor=white, style=filled];
# "BIOMG 1350" -> "BME 2210";
# "BIOG 1440" -> "BME 2210";
# "BME 2010" -> "BME 2210";
# "CHEM 2090" -> "BME 2210";
# "BME 3010" [fillcolor=black, fontcolor=white, style=filled];
# "BIOMG 3300" -> "BME 3010";
# "BIOG 1440" -> "BME 3010";
# "BME 2010" -> "BME 3010";
# "MATH 2930" -> "BME 3010";
# "BIOG 1445" -> "BME 3010";
# "BIOMG 1350" -> "BME 3010";
# "BME 3020" [fillcolor=white, fontcolor=black, style=filled];
# "BIOMG 1350" -> "BME 3020";
# "BIOG 1500" -> "BME 3020";
# "BME 3030" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2930" -> "BME 3030";
# "PHYS 2213" -> "BME 3030";
# "BME 3080" [fillcolor=black, fontcolor=white, style=filled];
# "BME 3081" [fillcolor=white, fontcolor=black, style=filled];
# "BME 3110" [fillcolor=white, fontcolor=black, style=filled];
# "BME 3010" -> "BME 3110";
# "CS 1112" -> "BME 3110";
# "MATH 2930" -> "BME 3110";
# "MATH 2940" -> "BME 3110";
# "BME 3020" -> "BME 3110";
# "BME 3210" [fillcolor=white, fontcolor=black, style=filled];
# "BME 2210" -> "BME 3210";
# "BME 3310" [fillcolor=white, fontcolor=black, style=filled];
# "BME 3410" [fillcolor=white, fontcolor=black, style=filled];
# "BME 3010" -> "BME 3410";
# "ENGRD 2020" -> "BME 3410";
# "MATH 2930" -> "BME 3410";
# "BME 4010" [fillcolor=black, fontcolor=white, style=filled];
# "BIOMG 1350" -> "BME 4010";
# "BIOG 1440" -> "BME 4010";
# "BME 2010" -> "BME 4010";
# "ENGRD 2020" -> "BME 4010";
# "BME 4020" [fillcolor=white, fontcolor=black, style=filled];
# "BME 2010" -> "BME 4020";
# "MATH 2930" -> "BME 4020";
# "BME 2000" -> "BME 4020";
# "PHYS 2213" -> "BME 4020";
# "BME 4080" [fillcolor=black, fontcolor=white, style=filled];
# "BME 4390" -> "BME 4080";
# "BME 3030" -> "BME 4080";
# "BME 4490" -> "BME 4080";
# "BME 4190" -> "BME 4080";
# "BME 4090" [fillcolor=white, fontcolor=black, style=filled];
# "BME 4080" -> "BME 4090";
# "BME 4190" [fillcolor=black, fontcolor=white, style=filled];
# "BME 3010" -> "BME 4190";
# "BME 3110" -> "BME 4190";
# "BME 3020" -> "BME 4190";
# "BME 3210" -> "BME 4190";
# "BME 4390" [fillcolor=black, fontcolor=white, style=filled];
# "CS 1112" -> "BME 4390";
# "BME 4440" [fillcolor=white, fontcolor=black, style=filled];
# "BME 4490" [fillcolor=black, fontcolor=white, style=filled];
# "BME 3410" -> "BME 4490";
# "BME 3210" -> "BME 4490";
# "BME 4900" [fillcolor=gray, fontcolor=black, style=filled];
# "BME 4901" [fillcolor=gray, fontcolor=black, style=filled];
# "BME 4900" -> "BME 4901";
# "BME 4910" [fillcolor=white, fontcolor=black, style=filled];
# "BIONB 2220" -> "BME 4910";
# "BME 4970" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 1560" [fillcolor=black, fontcolor=white, style=filled];
# "CHEM 1570" [fillcolor=white, fontcolor=black, style=filled];
# "CHEM 1560" -> "CHEM 1570";
# "CHEM 2070" -> "CHEM 1570";
# "CHEM 2070" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 2080" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 2090" -> "CHEM 2080";
# "CHEM 2070" -> "CHEM 2080";
# "CHEM 2090" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 2150" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1910" -> "CHEM 2150";
# "MATH 1110" -> "CHEM 2150";
# "CHEM 2510" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 3530" -> "CHEM 2510";
# "CHEM 3590" -> "CHEM 2510";
# "CHEM 3570" -> "CHEM 2510";
# "CHEM 1570" -> "CHEM 2510";
# "CHEM 3530" [fillcolor=black, fontcolor=white, style=filled];
# "CHEM 2090" -> "CHEM 3530";
# "CHEM 2080" -> "CHEM 3530";
# "CHEM 3570" [fillcolor=black, fontcolor=white, style=filled];
# "CHEM 2510" -> "CHEM 3570";
# "CHEM 2080" -> "CHEM 3570";
# "CHEM 3590" [fillcolor=white, fontcolor=black, style=filled];
# "CHEM 2150" -> "CHEM 3590";
# "CHEM 2080" -> "CHEM 3590";
# "CS 1112" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1910" -> "CS 1112";
# "MATH 1110" -> "CS 1112";
# "ENGRD 2020" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1112" -> "ENGRD 2020";
# "MATH 1920" -> "ENGRD 2020";
# "ENGRD 2202" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2930" -> "ENGRD 2202";
# "MATH 1106" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1106" -> "MATH 1120";
# "MATH 1110" -> "MATH 1120";
# "MATH 1910" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1910" -> "MATH 1920";
# "MATH 2210" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" -> "MATH 2210";
# "MATH 1110" -> "MATH 2210";
# "MATH 2220" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2210" -> "MATH 2220";
# "MATH 2230" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1120" -> "MATH 2230";
# "MATH 1110" -> "MATH 2230";
# "MATH 2240" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2230" -> "MATH 2240";
# "MATH 2930" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "MATH 2930";
# "MATH 2940" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "MATH 2940";
# "PHYS 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1112" -> "PHYS 1110";
# "PHYS 1116" -> "PHYS 1110";
# "PHYS 2217" -> "PHYS 1110";
# "PHYS 2213" -> "PHYS 1110";
# "PHYS 1112" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" -> "PHYS 1112";
# "PHYS 1112" -> "PHYS 1112";
# "PHYS 1110" -> "PHYS 1112";
# "PHYS 2213" -> "PHYS 1112";
# "MATH 1910" -> "PHYS 1112";
# "MATH 1920" -> "PHYS 1112";
# "PHYS 1116" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1910" -> "PHYS 1116";
# "PHYS 1110" -> "PHYS 1116";
# "PHYS 1116" -> "PHYS 1116";
# "MATH 1120" -> "PHYS 1116";
# "PHYS 2207" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1106" -> "PHYS 2207";
# "MATH 1110" -> "PHYS 2207";
# "PHYS 2213" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1112" -> "PHYS 2213";
# "MATH 2220" -> "PHYS 2213";
# "PHYS 2207" -> "PHYS 2213";
# "MATH 1920" -> "PHYS 2213";
# "MATH 2240" -> "PHYS 2213";
# "PHYS 2217" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1112" -> "PHYS 2217";
# "MATH 2220" -> "PHYS 2217";
# "PHYS 1116" -> "PHYS 2217";
# "MATH 1920" -> "PHYS 2217";
# "MATH 2240" -> "PHYS 2217";

# %%
course_list = get_course_list(['FA23', 'SP23'], 'CEE')
graph = PrerequisiteGraph(course_list)
graph.print_edges()
# Out:
# "AEM 2100" [fillcolor=black, fontcolor=white, style=filled];
# "BEE 2510" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2930" -> "BEE 2510";
# "CHEM 2090" -> "BEE 2510";
# "CHEM 2070" -> "BEE 2510";
# "BEE 3310" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1920" -> "BEE 3310";
# "ENGRD 2020" -> "BEE 3310";
# "MATH 2930" -> "BEE 3310";
# "MATH 1910" -> "BEE 3310";
# "BTRY 3010" [fillcolor=black, fontcolor=white, style=filled];
# "CEE 1130" [fillcolor=white, fontcolor=black, style=filled];
# "CEE 1160" [fillcolor=black, fontcolor=white, style=filled];
# "CEE 1165" [fillcolor=black, fontcolor=white, style=filled];
# "CEE 3040" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1920" -> "CEE 3040";
# "MATH 1910" -> "CEE 3040";
# "CEE 3080" [fillcolor=gray, fontcolor=black, style=filled];
# "CEE 3090" [fillcolor=gray, fontcolor=black, style=filled];
# "CEE 3101" [fillcolor=black, fontcolor=white, style=filled];
# "CEE 3102" [fillcolor=white, fontcolor=black, style=filled];
# "CEE 3200" [fillcolor=white, fontcolor=black, style=filled];
# "CS 1112" -> "CEE 3200";
# "CS 1110" -> "CEE 3200";
# "MATH 2940" -> "CEE 3200";
# "CEE 3230" [fillcolor=white, fontcolor=black, style=filled];
# "ENGRD 2700" -> "CEE 3230";
# "ILRST 2100" -> "CEE 3230";
# "BTRY 3010" -> "CEE 3230";
# "AEM 2100" -> "CEE 3230";
# "CEE 3040" -> "CEE 3230";
# "CEE 3310" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2930" -> "CEE 3310";
# "CEE 3410" [fillcolor=black, fontcolor=white, style=filled];
# "ENGRD 2020" -> "CEE 3410";
# "CEE 3510" [fillcolor=white, fontcolor=black, style=filled];
# "ENGRD 2510" -> "CEE 3510";
# "MATH 2930" -> "CEE 3510";
# "CEE 3610" [fillcolor=white, fontcolor=black, style=filled];
# "CEE 3710" [fillcolor=white, fontcolor=black, style=filled];
# "ENGRD 2020" -> "CEE 3710";
# "MATH 2940" -> "CEE 3710";
# "CEE 3790" [fillcolor=black, fontcolor=white, style=filled];
# "CEE 4000" [fillcolor=gray, fontcolor=black, style=filled];
# "CEE 4010" [fillcolor=gray, fontcolor=black, style=filled];
# "CEE 4090" [fillcolor=gray, fontcolor=black, style=filled];
# "CEE 4210" [fillcolor=black, fontcolor=white, style=filled];
# "CEE 3310" -> "CEE 4210";
# "BEE 3310" -> "CEE 4210";
# "PHYS 2213" -> "CEE 4210";
# "CEE 4330" [fillcolor=white, fontcolor=black, style=filled];
# "CEE 3310" -> "CEE 4330";
# "ENGRD 3200" -> "CEE 4330";
# "CEE 4510" [fillcolor=black, fontcolor=white, style=filled];
# "CHEM 1570" -> "CEE 4510";
# "CHEM 2090" -> "CEE 4510";
# "CEE 4520" [fillcolor=black, fontcolor=white, style=filled];
# "CEE 4210" -> "CEE 4520";
# "CEE 3510" -> "CEE 4520";
# "CEE 4530" [fillcolor=white, fontcolor=black, style=filled];
# "CEE 3510" -> "CEE 4530";
# "CEE 4535" [fillcolor=black, fontcolor=white, style=filled];
# "CHEM 2090" -> "CEE 4535";
# "CEE 4555" [fillcolor=black, fontcolor=white, style=filled];
# "CEE 3510" -> "CEE 4555";
# "CEE 4565" [fillcolor=white, fontcolor=black, style=filled];
# "CEE 3510" -> "CEE 4565";
# "BEE 2510" -> "CEE 4565";
# "CEE 4570" [fillcolor=black, fontcolor=white, style=filled];
# "CEE 3510" -> "CEE 4570";
# "CEE 4590" [fillcolor=white, fontcolor=black, style=filled];
# "CEE 4565" -> "CEE 4590";
# "CEE 4640" [fillcolor=black, fontcolor=white, style=filled];
# "CEE 3610" -> "CEE 4640";
# "CEE 3040" -> "CEE 4640";
# "CEE 4665" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2940" -> "CEE 4665";
# "CEE 4740" [fillcolor=white, fontcolor=black, style=filled];
# "CEE 3710" -> "CEE 4740";
# "ENGRD 2020" -> "CEE 4740";
# "CEE 4745" [fillcolor=black, fontcolor=white, style=filled];
# "CEE 3710" -> "CEE 4745";
# "CEE 3080" -> "CEE 4745";
# "CEE 4750" [fillcolor=white, fontcolor=black, style=filled];
# "CEE 4760" [fillcolor=black, fontcolor=white, style=filled];
# "CEE 3710" -> "CEE 4760";
# "CEE 4770" [fillcolor=black, fontcolor=white, style=filled];
# "CEE 4780" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2940" -> "CEE 4780";
# "CEE 4795" [fillcolor=white, fontcolor=black, style=filled];
# "CEE 3200" -> "CEE 4795";
# "CEE 3040" -> "CEE 4795";
# "CEE 4800" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2940" -> "CEE 4800";
# "CEE 4880" [fillcolor=white, fontcolor=black, style=filled];
# "CEE 4930" [fillcolor=black, fontcolor=white, style=filled];
# "CEE 3230" -> "CEE 4930";
# "CEE 3040" -> "CEE 4930";
# "CHEM 1560" [fillcolor=black, fontcolor=white, style=filled];
# "CHEM 1570" [fillcolor=white, fontcolor=black, style=filled];
# "CHEM 1560" -> "CHEM 1570";
# "CHEM 2070" -> "CHEM 1570";
# "CHEM 2070" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 2090" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1112" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1110" -> "CS 1112";
# "MATH 1910" -> "CS 1112";
# "ENGRD 2020" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "ENGRD 2020";
# "PHYS 1112" -> "ENGRD 2020";
# "ENGRD 2510" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2930" -> "ENGRD 2510";
# "CHEM 2090" -> "ENGRD 2510";
# "CHEM 2070" -> "ENGRD 2510";
# "ENGRD 2700" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "ENGRD 2700";
# "MATH 1910" -> "ENGRD 2700";
# "ENGRD 3200" [fillcolor=white, fontcolor=black, style=filled];
# "CS 1112" -> "ENGRD 3200";
# "CS 1110" -> "ENGRD 3200";
# "MATH 2940" -> "ENGRD 3200";
# "ILRST 2100" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1106" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1106" -> "MATH 1120";
# "MATH 1110" -> "MATH 1120";
# "MATH 1910" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1910" -> "MATH 1920";
# "MATH 2210" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1110" -> "MATH 2210";
# "MATH 1120" -> "MATH 2210";
# "MATH 2220" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2210" -> "MATH 2220";
# "MATH 2230" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1110" -> "MATH 2230";
# "MATH 1120" -> "MATH 2230";
# "MATH 2240" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2230" -> "MATH 2240";
# "MATH 2930" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "MATH 2930";
# "MATH 2940" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "MATH 2940";
# "PHYS 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 2213" -> "PHYS 1110";
# "PHYS 1116" -> "PHYS 1110";
# "PHYS 1112" -> "PHYS 1110";
# "PHYS 2217" -> "PHYS 1110";
# "PHYS 1112" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" -> "PHYS 1112";
# "PHYS 1110" -> "PHYS 1112";
# "PHYS 2213" -> "PHYS 1112";
# "MATH 1910" -> "PHYS 1112";
# "MATH 1920" -> "PHYS 1112";
# "PHYS 1112" -> "PHYS 1112";
# "PHYS 1116" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1110" -> "PHYS 1116";
# "PHYS 1116" -> "PHYS 1116";
# "MATH 1910" -> "PHYS 1116";
# "MATH 1120" -> "PHYS 1116";
# "PHYS 2207" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1106" -> "PHYS 2207";
# "MATH 1110" -> "PHYS 2207";
# "PHYS 2213" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2220" -> "PHYS 2213";
# "MATH 2240" -> "PHYS 2213";
# "MATH 1920" -> "PHYS 2213";
# "PHYS 2207" -> "PHYS 2213";
# "PHYS 1112" -> "PHYS 2213";
# "PHYS 2217" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2220" -> "PHYS 2217";
# "PHYS 1116" -> "PHYS 2217";
# "MATH 2240" -> "PHYS 2217";
# "MATH 1920" -> "PHYS 2217";
# "PHYS 1112" -> "PHYS 2217";

# %%
course_list = get_course_list(['FA23', 'SP23'], 'CHEME')
graph = PrerequisiteGraph(course_list)
graph.print_edges()
# Out:
# "BIOG 1500" [fillcolor=gray, fontcolor=black, style=filled];
# "BIOMG 1350" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 2070" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 2080" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 2090" -> "CHEM 2080";
# "CHEM 2070" -> "CHEM 2080";
# "CHEM 2090" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 3890" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2310" -> "CHEM 3890";
# "PHYS 2208" -> "CHEM 3890";
# "CHEM 2080" -> "CHEM 3890";
# "MATH 2220" -> "CHEM 3890";
# "MATH 2130" -> "CHEM 3890";
# "CHEME 1800" [fillcolor=white, fontcolor=black, style=filled];
# "CHEME 2000" [fillcolor=black, fontcolor=white, style=filled];
# "CHEME 2200" [fillcolor=white, fontcolor=black, style=filled];
# "ENGRD 2190" -> "CHEME 2200";
# "PHYS 2213" -> "CHEME 2200";
# "MATH 2930" -> "CHEME 2200";
# "CHEM 3890" -> "CHEME 2200";
# "CHEME 3010" [fillcolor=white, fontcolor=black, style=filled];
# "CHEME 3130" [fillcolor=black, fontcolor=white, style=filled];
# "CHEME 2200" -> "CHEME 3130";
# "CHEME 3230" [fillcolor=white, fontcolor=black, style=filled];
# "ENGRD 2190" -> "CHEME 3230";
# "MATH 2930" -> "CHEME 3230";
# "CHEME 3240" [fillcolor=black, fontcolor=white, style=filled];
# "CHEME 3230" -> "CHEME 3240";
# "CHEME 3320" [fillcolor=white, fontcolor=black, style=filled];
# "CHEME 3130" -> "CHEME 3320";
# "CHEME 3240" -> "CHEME 3320";
# "CHEME 3720" [fillcolor=white, fontcolor=black, style=filled];
# "CHEME 3230" -> "CHEME 3720";
# "CHEME 3130" -> "CHEME 3720";
# "CHEME 3900" [fillcolor=white, fontcolor=black, style=filled];
# "CHEME 3130" -> "CHEME 3900";
# "CHEME 3320" -> "CHEME 3900";
# "CHEME 3240" -> "CHEME 3900";
# "CHEME 4020" [fillcolor=white, fontcolor=black, style=filled];
# "BIOG 1500" -> "CHEME 4020";
# "BIOMG 1350" -> "CHEME 4020";
# "CHEME 4130" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 2214" -> "CHEME 4130";
# "MATH 2940" -> "CHEME 4130";
# "CHEME 4320" [fillcolor=black, fontcolor=white, style=filled];
# "CHEME 3240" -> "CHEME 4320";
# "CHEME 3900" -> "CHEME 4320";
# "CHEME 3230" -> "CHEME 4320";
# "CHEME 3320" -> "CHEME 4320";
# "CHEME 3720" -> "CHEME 4320";
# "CHEME 4620" [fillcolor=white, fontcolor=black, style=filled];
# "CHEME 4320" -> "CHEME 4620";
# "CHEME 4800" [fillcolor=white, fontcolor=black, style=filled];
# "CHEME 4840" [fillcolor=black, fontcolor=white, style=filled];
# "CHEME 3900" -> "CHEME 4840";
# "CHEME 4880" [fillcolor=black, fontcolor=white, style=filled];
# "CHEME 4900" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEME 4998" [fillcolor=gray, fontcolor=black, style=filled];
# "ENGRD 2190" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1106" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1106" -> "MATH 1120";
# "MATH 1110" -> "MATH 1120";
# "MATH 1910" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1910" -> "MATH 1920";
# "MATH 2130" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1120" -> "MATH 2130";
# "MATH 1910" -> "MATH 2130";
# "MATH 2210" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" -> "MATH 2210";
# "MATH 1110" -> "MATH 2210";
# "MATH 2220" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2210" -> "MATH 2220";
# "MATH 2230" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1120" -> "MATH 2230";
# "MATH 1110" -> "MATH 2230";
# "MATH 2240" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2230" -> "MATH 2240";
# "MATH 2310" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1106" -> "MATH 2310";
# "MATH 1110" -> "MATH 2310";
# "MATH 2930" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "MATH 2930";
# "MATH 2940" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "MATH 2940";
# "PHYS 1101" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 2217" -> "PHYS 1110";
# "PHYS 1112" -> "PHYS 1110";
# "PHYS 2213" -> "PHYS 1110";
# "PHYS 1116" -> "PHYS 1110";
# "PHYS 1112" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" -> "PHYS 1112";
# "MATH 1910" -> "PHYS 1112";
# "MATH 1920" -> "PHYS 1112";
# "PHYS 1110" -> "PHYS 1112";
# "PHYS 2213" -> "PHYS 1112";
# "PHYS 1112" -> "PHYS 1112";
# "PHYS 1116" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" -> "PHYS 1116";
# "PHYS 1110" -> "PHYS 1116";
# "MATH 1910" -> "PHYS 1116";
# "PHYS 1116" -> "PHYS 1116";
# "PHYS 2207" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1106" -> "PHYS 2207";
# "MATH 1110" -> "PHYS 2207";
# "PHYS 2208" [fillcolor=white, fontcolor=black, style=filled];
# "PHYS 1101" -> "PHYS 2208";
# "PHYS 1112" -> "PHYS 2208";
# "PHYS 2207" -> "PHYS 2208";
# "PHYS 2213" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "PHYS 2213";
# "MATH 2240" -> "PHYS 2213";
# "MATH 2220" -> "PHYS 2213";
# "PHYS 1112" -> "PHYS 2213";
# "PHYS 2207" -> "PHYS 2213";
# "PHYS 2214" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 2208" -> "PHYS 2214";
# "MATH 1920" -> "PHYS 2214";
# "MATH 2240" -> "PHYS 2214";
# "PHYS 2213" -> "PHYS 2214";
# "MATH 2220" -> "PHYS 2214";
# "MATH 2130" -> "PHYS 2214";
# "PHYS 2217" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "PHYS 2217";
# "MATH 2240" -> "PHYS 2217";
# "PHYS 1116" -> "PHYS 2217";
# "MATH 2220" -> "PHYS 2217";
# "PHYS 1112" -> "PHYS 2217";

# %%
course_list = get_course_list(['FA23', 'SP23'], 'ECE')
graph = PrerequisiteGraph(course_list)
graph.print_edges()
# Out:
# Class not found: AEP 6620
# Class not found: AEP 6620
# "AEP 3200" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2940" -> "AEP 3200";
# "MATH 2930" -> "AEP 3200";
# "AEP 3550" [fillcolor=white, fontcolor=black, style=filled];
# "AEP 4200" -> "AEP 3550";
# "PHYS 2217" -> "AEP 3550";
# "PHYS 2213" -> "AEP 3550";
# "AEP 4200" [fillcolor=black, fontcolor=white, style=filled];
# "AEP 3200" -> "AEP 4200";
# "AEP 6620" [fillcolor=white, fontcolor=black, style=filled];
# "BIONB 2220" [fillcolor=white, fontcolor=black, style=filled];
# "BTRY 3010" [fillcolor=black, fontcolor=white, style=filled];
# "CHEM 2090" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1112" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1110" -> "CS 1112";
# "MATH 1910" -> "CS 1112";
# "CS 1133" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 2024" [fillcolor=black, fontcolor=white, style=filled];
# "CS 2110" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1112" -> "CS 2110";
# "CS 1110" -> "CS 2110";
# "CS 3410" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 2110" -> "CS 3410";
# "CS 2024" -> "CS 3410";
# "CS 3420" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 2300" -> "CS 3420";
# "ECE 2400" -> "CS 3420";
# "ENGRD 2140" -> "CS 3420";
# "ENGRD 2300" -> "CS 3420";
# "ECE 1210" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 2100" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "ECE 2100";
# "MATH 2930" -> "ECE 2100";
# "PHYS 2213" -> "ECE 2100";
# "PHYS 1112" -> "ECE 2100";
# "ECE 2300" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1112" -> "ECE 2300";
# "CS 1110" -> "ECE 2300";
# "ECE 2400" [fillcolor=black, fontcolor=white, style=filled];
# "CS 1112" -> "ECE 2400";
# "CS 1110" -> "ECE 2400";
# "ECE 2720" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "ECE 2720";
# "MATH 2940" -> "ECE 2720";
# "CS 1112" -> "ECE 2720";
# "CS 1110" -> "ECE 2720";
# "ECE 3030" [fillcolor=black, fontcolor=white, style=filled];
# "ECE 2100" -> "ECE 3030";
# "PHYS 2213" -> "ECE 3030";
# "MATH 2930" -> "ECE 3030";
# "ENGRD 2100" -> "ECE 3030";
# "ECE 3100" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2940" -> "ECE 3100";
# "PHYS 2213" -> "ECE 3100";
# "ECE 3140" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 2300" -> "ECE 3140";
# "ECE 2400" -> "ECE 3140";
# "ENGRD 2140" -> "ECE 3140";
# "ENGRD 2300" -> "ECE 3140";
# "ECE 3150" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 2100" -> "ECE 3150";
# "ENGRD 2100" -> "ECE 3150";
# "ECE 3250" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2940" -> "ECE 3250";
# "MATH 2930" -> "ECE 3250";
# "ECE 4060" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2930" -> "ECE 4060";
# "PHYS 2214" -> "ECE 4060";
# "ECE 4070" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 4060" -> "ECE 4070";
# "ECE 4110" [fillcolor=black, fontcolor=white, style=filled];
# "ECE 3250" -> "ECE 4110";
# "ECE 2720" -> "ECE 4110";
# "ECE 3100" -> "ECE 4110";
# "ECE 4130" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2940" -> "ECE 4130";
# "PHYS 2214" -> "ECE 4130";
# "ECE 4150" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 4160" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 4180" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 4200" [fillcolor=white, fontcolor=black, style=filled];
# "STSCI 3080" -> "ECE 4200";
# "MATH 2940" -> "ECE 4200";
# "ECE 3250" -> "ECE 4200";
# "ECE 3100" -> "ECE 4200";
# "ECE 4230" [fillcolor=black, fontcolor=white, style=filled];
# "ECE 2720" -> "ECE 4230";
# "ECE 4240" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2940" -> "ECE 4240";
# "MATH 4710" -> "ECE 4240";
# "ENGRD 2720" -> "ECE 4240";
# "ENGRD 2112" -> "ECE 4240";
# "ENGRD 2700" -> "ECE 4240";
# "ECE 4250" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1920" -> "ECE 4250";
# "MATH 2940" -> "ECE 4250";
# "ECE 3250" -> "ECE 4250";
# "ECE 3100" -> "ECE 4250";
# "ECE 2720" -> "ECE 4250";
# "ECE 4300" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 3030" -> "ECE 4300";
# "ECE 4320" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 2100" -> "ECE 4320";
# "ECE 4330" [fillcolor=black, fontcolor=white, style=filled];
# "ECE 3030" -> "ECE 4330";
# "ECE 3150" -> "ECE 4330";
# "ECE 4360" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2940" -> "ECE 4360";
# "ECE 3150" -> "ECE 4360";
# "CHEM 2090" -> "ECE 4360";
# "MSE 2620" -> "ECE 4360";
# "MATH 2930" -> "ECE 4360";
# "ECE 4361" [fillcolor=black, fontcolor=white, style=filled];
# "MSE 5410" -> "ECE 4361";
# "ECE 4360" -> "ECE 4361";
# "AEP 6620" -> "ECE 4361";
# "ECE 4370" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 3030" -> "ECE 4370";
# "ECE 4380" [fillcolor=white, fontcolor=black, style=filled];
# "AEP 3550" -> "ECE 4380";
# "ECE 3030" -> "ECE 4380";
# "ECE 4450" [fillcolor=gray, fontcolor=black, style=filled];
# "ECE 3100" -> "ECE 4450";
# "ECE 4510" [fillcolor=black, fontcolor=white, style=filled];
# "ECE 3250" -> "ECE 4510";
# "ECE 4520" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 2100" -> "ECE 4520";
# "ECE 4510" -> "ECE 4520";
# "ECE 3100" -> "ECE 4520";
# "ECE 4530" [fillcolor=black, fontcolor=white, style=filled];
# "ECE 3150" -> "ECE 4530";
# "ECE 4560" [fillcolor=black, fontcolor=white, style=filled];
# "ECE 3150" -> "ECE 4560";
# "ECE 4570" [fillcolor=black, fontcolor=white, style=filled];
# "ECE 3150" -> "ECE 4570";
# "ECE 4670" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 3250" -> "ECE 4670";
# "ECE 3100" -> "ECE 4670";
# "ECE 4740" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 3150" -> "ECE 4740";
# "ECE 4750" [fillcolor=black, fontcolor=white, style=filled];
# "CS 3410" -> "ECE 4750";
# "ECE 3140" -> "ECE 4750";
# "CS 3420" -> "ECE 4750";
# "ECE 4760" [fillcolor=black, fontcolor=white, style=filled];
# "ECE 3140" -> "ECE 4760";
# "CS 3420" -> "ECE 4760";
# "ECE 4770" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1920" -> "ECE 4770";
# "MATH 2940" -> "ECE 4770";
# "MATH 4710" -> "ECE 4770";
# "CS 1133" -> "ECE 4770";
# "ENGRD 2700" -> "ECE 4770";
# "CS 1110" -> "ECE 4770";
# "MATH 2210" -> "ECE 4770";
# "ECE 4800" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1920" -> "ECE 4800";
# "MATH 2940" -> "ECE 4800";
# "ECE 3250" -> "ECE 4800";
# "ECE 4840" [fillcolor=white, fontcolor=black, style=filled];
# "PHYS 2213" -> "ECE 4840";
# "PHYS 1112" -> "ECE 4840";
# "PHYS 2214" -> "ECE 4840";
# "ECE 4880" [fillcolor=black, fontcolor=white, style=filled];
# "ECE 3030" -> "ECE 4880";
# "ECE 4910" [fillcolor=white, fontcolor=black, style=filled];
# "BIONB 2220" -> "ECE 4910";
# "ECE 4920" [fillcolor=gray, fontcolor=black, style=filled];
# "ECE 4760" -> "ECE 4920";
# "ECE 5760" -> "ECE 4920";
# "ECE 4950" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 4960" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 4980" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 4990" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 4999" [fillcolor=gray, fontcolor=black, style=filled];
# "ECE 5725" [fillcolor=gray, fontcolor=black, style=filled];
# "ECE 3140" -> "ECE 5725";
# "CS 3420" -> "ECE 5725";
# "ECE 5760" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 5725" -> "ECE 5760";
# "ENGRD 2100" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "ENGRD 2100";
# "MATH 2930" -> "ENGRD 2100";
# "PHYS 2213" -> "ENGRD 2100";
# "PHYS 1112" -> "ENGRD 2100";
# "ENGRD 2112" [fillcolor=black, fontcolor=white, style=filled];
# "CS 1110" -> "ENGRD 2112";
# "ENGRD 2140" [fillcolor=black, fontcolor=white, style=filled];
# "CS 1112" -> "ENGRD 2140";
# "CS 1110" -> "ENGRD 2140";
# "ENGRD 2300" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1112" -> "ENGRD 2300";
# "CS 1110" -> "ENGRD 2300";
# "ENGRD 2700" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "ENGRD 2700";
# "MATH 1910" -> "ENGRD 2700";
# "ENGRD 2720" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "ENGRD 2720";
# "CS 1112" -> "ENGRD 2720";
# "CS 1110" -> "ENGRD 2720";
# "MATH 1106" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1110" -> "MATH 1120";
# "MATH 1106" -> "MATH 1120";
# "MATH 1910" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1910" -> "MATH 1920";
# "MATH 2130" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1910" -> "MATH 2130";
# "MATH 1120" -> "MATH 2130";
# "MATH 2210" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1110" -> "MATH 2210";
# "MATH 1120" -> "MATH 2210";
# "MATH 2220" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2210" -> "MATH 2220";
# "MATH 2230" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1110" -> "MATH 2230";
# "MATH 1120" -> "MATH 2230";
# "MATH 2240" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2230" -> "MATH 2240";
# "MATH 2930" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "MATH 2930";
# "MATH 2940" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "MATH 2940";
# "MATH 4710" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1110" -> "MATH 4710";
# "MATH 1120" -> "MATH 4710";
# "MSE 2620" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1920" -> "MSE 2620";
# "PHYS 2213" -> "MSE 2620";
# "MSE 5410" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2940" -> "MSE 5410";
# "ECE 3150" -> "MSE 5410";
# "CHEM 2090" -> "MSE 5410";
# "MSE 2620" -> "MSE 5410";
# "MATH 2930" -> "MSE 5410";
# "PHYS 1101" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1116" -> "PHYS 1110";
# "PHYS 2217" -> "PHYS 1110";
# "PHYS 2213" -> "PHYS 1110";
# "PHYS 1112" -> "PHYS 1110";
# "PHYS 1112" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "PHYS 1112";
# "MATH 1120" -> "PHYS 1112";
# "PHYS 1112" -> "PHYS 1112";
# "PHYS 2213" -> "PHYS 1112";
# "PHYS 1110" -> "PHYS 1112";
# "MATH 1910" -> "PHYS 1112";
# "PHYS 1116" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1910" -> "PHYS 1116";
# "PHYS 1116" -> "PHYS 1116";
# "PHYS 1110" -> "PHYS 1116";
# "MATH 1120" -> "PHYS 1116";
# "PHYS 2207" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1110" -> "PHYS 2207";
# "MATH 1106" -> "PHYS 2207";
# "PHYS 2208" [fillcolor=white, fontcolor=black, style=filled];
# "PHYS 2207" -> "PHYS 2208";
# "PHYS 1101" -> "PHYS 2208";
# "PHYS 1112" -> "PHYS 2208";
# "PHYS 2213" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "PHYS 2213";
# "PHYS 2207" -> "PHYS 2213";
# "PHYS 1112" -> "PHYS 2213";
# "MATH 2240" -> "PHYS 2213";
# "MATH 2220" -> "PHYS 2213";
# "PHYS 2214" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "PHYS 2214";
# "MATH 2130" -> "PHYS 2214";
# "PHYS 2213" -> "PHYS 2214";
# "PHYS 2208" -> "PHYS 2214";
# "MATH 2240" -> "PHYS 2214";
# "MATH 2220" -> "PHYS 2214";
# "PHYS 2217" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "PHYS 2217";
# "PHYS 1112" -> "PHYS 2217";
# "PHYS 1116" -> "PHYS 2217";
# "MATH 2240" -> "PHYS 2217";
# "MATH 2220" -> "PHYS 2217";
# "STSCI 2150" [fillcolor=gray, fontcolor=black, style=filled];
# "STSCI 2200" [fillcolor=black, fontcolor=white, style=filled];
# "STSCI 3080" [fillcolor=gray, fontcolor=black, style=filled];
# "STSCI 2200" -> "STSCI 3080";
# "BTRY 3010" -> "STSCI 3080";
# "STSCI 2150" -> "STSCI 3080";
# "MATH 2130" -> "STSCI 3080";

# %%
course_list = get_course_list(['FA23', 'SP23'], 'MAE')
graph = PrerequisiteGraph(course_list)
graph.print_edges()
# Out:
# "BEE 2220" [fillcolor=white, fontcolor=black, style=filled];
# "PHYS 2213" -> "BEE 2220";
# "MATH 1920" -> "BEE 2220";
# "BEE 3310" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2930" -> "BEE 3310";
# "MATH 1920" -> "BEE 3310";
# "ENGRD 2020" -> "BEE 3310";
# "MATH 1910" -> "BEE 3310";
# "BEE 3500" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2930" -> "BEE 3500";
# "BIOG 1440" [fillcolor=gray, fontcolor=black, style=filled];
# "BIOMG 1350" [fillcolor=gray, fontcolor=black, style=filled];
# "BME 2010" [fillcolor=white, fontcolor=black, style=filled];
# "CHEM 2090" -> "BME 2010";
# "BIOMG 1350" -> "BME 2010";
# "CEE 3310" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2930" -> "CEE 3310";
# "CHEM 2070" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 2080" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 2070" -> "CHEM 2080";
# "CHEM 2090" -> "CHEM 2080";
# "CHEM 2090" [fillcolor=gray, fontcolor=black, style=filled];
# "CHEM 3890" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2220" -> "CHEM 3890";
# "MATH 2130" -> "CHEM 3890";
# "MATH 2310" -> "CHEM 3890";
# "PHYS 2208" -> "CHEM 3890";
# "CHEM 2080" -> "CHEM 3890";
# "CHEME 2200" [fillcolor=white, fontcolor=black, style=filled];
# "CHEM 3890" -> "CHEME 2200";
# "PHYS 2213" -> "CHEME 2200";
# "MATH 2930" -> "CHEME 2200";
# "ENGRD 2190" -> "CHEME 2200";
# "CHEME 3130" [fillcolor=black, fontcolor=white, style=filled];
# "CHEME 2200" -> "CHEME 3130";
# "CHEME 3230" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2930" -> "CHEME 3230";
# "ENGRD 2190" -> "CHEME 3230";
# "CHEME 3240" [fillcolor=black, fontcolor=white, style=filled];
# "CHEME 3230" -> "CHEME 3240";
# "CHEME 3720" [fillcolor=white, fontcolor=black, style=filled];
# "CHEME 3230" -> "CHEME 3720";
# "CHEME 3130" -> "CHEME 3720";
# "CS 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1112" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1110" -> "CS 1112";
# "MATH 1910" -> "CS 1112";
# "CS 1133" [fillcolor=gray, fontcolor=black, style=filled];
# "ECE 2100" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1112" -> "ECE 2100";
# "PHYS 2213" -> "ECE 2100";
# "MATH 1920" -> "ECE 2100";
# "MATH 2930" -> "ECE 2100";
# "ECE 2300" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1112" -> "ECE 2300";
# "CS 1110" -> "ECE 2300";
# "ECE 2400" [fillcolor=black, fontcolor=white, style=filled];
# "CS 1112" -> "ECE 2400";
# "CS 1110" -> "ECE 2400";
# "ECE 3250" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2930" -> "ECE 3250";
# "MATH 2940" -> "ECE 3250";
# "ECE 3400" [fillcolor=black, fontcolor=white, style=filled];
# "ECE 3250" -> "ECE 3400";
# "ECE 2400" -> "ECE 3400";
# "ECE 2300" -> "ECE 3400";
# "ECE 2100" -> "ECE 3400";
# "ENGRD 2020" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1112" -> "ENGRD 2020";
# "MATH 1920" -> "ENGRD 2020";
# "ENGRD 2112" [fillcolor=black, fontcolor=white, style=filled];
# "CS 1110" -> "ENGRD 2112";
# "ENGRD 2190" [fillcolor=black, fontcolor=white, style=filled];
# "ENGRD 2210" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 1112" -> "ENGRD 2210";
# "MATH 1920" -> "ENGRD 2210";
# "ENGRD 2610" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 1112" -> "ENGRD 2610";
# "ENGRD 2700" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "ENGRD 2700";
# "MATH 1910" -> "ENGRD 2700";
# "ENGRD 2720" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1112" -> "ENGRD 2720";
# "MATH 1920" -> "ENGRD 2720";
# "CS 1110" -> "ENGRD 2720";
# "MAE 1170" [fillcolor=black, fontcolor=white, style=filled];
# "MAE 1270" [fillcolor=black, fontcolor=white, style=filled];
# "MAE 1900" [fillcolor=gray, fontcolor=black, style=filled];
# "MAE 2020" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1112" -> "MAE 2020";
# "MATH 1920" -> "MAE 2020";
# "MAE 2030" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2930" -> "MAE 2030";
# "ENGRD 2020" -> "MAE 2030";
# "MATH 2940" -> "MAE 2030";
# "MAE 2210" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 1112" -> "MAE 2210";
# "MATH 1920" -> "MAE 2210";
# "MAE 2250" [fillcolor=white, fontcolor=black, style=filled];
# "MAE 2030" -> "MAE 2250";
# "ENGRD 2020" -> "MAE 2250";
# "MAE 2270" [fillcolor=black, fontcolor=white, style=filled];
# "MAE 3050" [fillcolor=black, fontcolor=white, style=filled];
# "ENGRD 2210" -> "MAE 3050";
# "BEE 3310" -> "MAE 3050";
# "MAE 2030" -> "MAE 3050";
# "CEE 3310" -> "MAE 3050";
# "CHEME 3230" -> "MAE 3050";
# "BEE 2220" -> "MAE 3050";
# "MAE 3230" -> "MAE 3050";
# "MAE 3120" [fillcolor=black, fontcolor=white, style=filled];
# "MSE 3040" -> "MAE 3120";
# "MAE 3130" -> "MAE 3120";
# "MSE 2610" -> "MAE 3120";
# "ENGRD 2020" -> "MAE 3120";
# "MSE 2060" -> "MAE 3120";
# "MAE 3130" [fillcolor=white, fontcolor=black, style=filled];
# "MSE 2610" -> "MAE 3130";
# "MAE 3230" [fillcolor=black, fontcolor=white, style=filled];
# "MAE 2030" -> "MAE 3230";
# "ENGRD 2210" -> "MAE 3230";
# "ENGRD 2020" -> "MAE 3230";
# "MAE 3240" [fillcolor=white, fontcolor=black, style=filled];
# "MAE 3230" -> "MAE 3240";
# "MAE 3260" [fillcolor=black, fontcolor=white, style=filled];
# "MAE 2030" -> "MAE 3260";
# "MATH 2930" -> "MAE 3260";
# "MATH 2940" -> "MAE 3260";
# "MAE 3270" [fillcolor=black, fontcolor=white, style=filled];
# "CS 1112" -> "MAE 3270";
# "CS 1110" -> "MAE 3270";
# "ENGRD 2020" -> "MAE 3270";
# "MATH 2940" -> "MAE 3270";
# "MAE 3780" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 2213" -> "MAE 3780";
# "CS 1112" -> "MAE 3780";
# "CS 1110" -> "MAE 3780";
# "MATH 2930" -> "MAE 3780";
# "MAE 3870" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 2213" -> "MAE 3870";
# "MAE 2030" -> "MAE 3870";
# "MATH 2930" -> "MAE 3870";
# "MAE 4020" [fillcolor=black, fontcolor=white, style=filled];
# "MAE 3270" -> "MAE 4020";
# "MAE 3050" -> "MAE 4020";
# "MAE 3230" -> "MAE 4020";
# "MAE 4021" [fillcolor=black, fontcolor=white, style=filled];
# "MAE 3270" -> "MAE 4021";
# "MAE 3050" -> "MAE 4021";
# "MAE 3230" -> "MAE 4021";
# "MAE 4060" [fillcolor=black, fontcolor=white, style=filled];
# "MAE 2030" -> "MAE 4060";
# "MATH 2930" -> "MAE 4060";
# "MATH 2940" -> "MAE 4060";
# "MAE 4070" [fillcolor=black, fontcolor=white, style=filled];
# "MAE 3260" -> "MAE 4070";
# "MAE 3050" -> "MAE 4070";
# "MAE 3230" -> "MAE 4070";
# "MAE 4130" [fillcolor=white, fontcolor=black, style=filled];
# "MAE 4131" [fillcolor=white, fontcolor=black, style=filled];
# "MAE 3270" -> "MAE 4131";
# "MAE 4150" [fillcolor=white, fontcolor=black, style=filled];
# "MAE 4160" [fillcolor=white, fontcolor=black, style=filled];
# "MAE 3260" -> "MAE 4160";
# "MAE 4060" -> "MAE 4160";
# "MAE 4161" [fillcolor=white, fontcolor=black, style=filled];
# "MAE 3260" -> "MAE 4161";
# "MAE 4060" -> "MAE 4161";
# "MAE 4180" [fillcolor=white, fontcolor=black, style=filled];
# "MAE 4190" [fillcolor=white, fontcolor=black, style=filled];
# "MAE 4220" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 3400" -> "MAE 4220";
# "MAE 3780" -> "MAE 4220";
# "MAE 4221" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 3400" -> "MAE 4221";
# "MAE 3780" -> "MAE 4221";
# "MAE 4230" [fillcolor=white, fontcolor=black, style=filled];
# "BEE 3310" -> "MAE 4230";
# "CHEME 3230" -> "MAE 4230";
# "CEE 3310" -> "MAE 4230";
# "MAE 3230" -> "MAE 4230";
# "MAE 4231" [fillcolor=white, fontcolor=black, style=filled];
# "BEE 3310" -> "MAE 4231";
# "CHEME 3230" -> "MAE 4231";
# "CEE 3310" -> "MAE 4231";
# "MAE 3230" -> "MAE 4231";
# "MAE 4240" [fillcolor=black, fontcolor=white, style=filled];
# "ENGRD 2610" -> "MAE 4240";
# "ENGRD 2020" -> "MAE 4240";
# "MAE 4272" [fillcolor=black, fontcolor=white, style=filled];
# "MAE 3240" -> "MAE 4272";
# "MAE 3230" -> "MAE 4272";
# "MAE 4291" [fillcolor=gray, fontcolor=black, style=filled];
# "MAE 4300" -> "MAE 4291";
# "MAE 4300" [fillcolor=black, fontcolor=white, style=filled];
# "MAE 4320" [fillcolor=white, fontcolor=black, style=filled];
# "ECE 2100" -> "MAE 4320";
# "MAE 4341" [fillcolor=black, fontcolor=white, style=filled];
# "MAE 4351" [fillcolor=black, fontcolor=white, style=filled];
# "MAE 4440" [fillcolor=black, fontcolor=white, style=filled];
# "MAE 3240" -> "MAE 4440";
# "MAE 3230" -> "MAE 4440";
# "MAE 4441" [fillcolor=black, fontcolor=white, style=filled];
# "MAE 3240" -> "MAE 4441";
# "MAE 3230" -> "MAE 4441";
# "MAE 4480" [fillcolor=black, fontcolor=white, style=filled];
# "MAE 4510" [fillcolor=white, fontcolor=black, style=filled];
# "ENGRD 2210" -> "MAE 4510";
# "MAE 3050" -> "MAE 4510";
# "MAE 3230" -> "MAE 4510";
# "MAE 2210" -> "MAE 4510";
# "MAE 4530" [fillcolor=white, fontcolor=black, style=filled];
# "BEE 3500" -> "MAE 4530";
# "CHEME 3240" -> "MAE 4530";
# "MAE 3240" -> "MAE 4530";
# "MAE 4540" [fillcolor=black, fontcolor=white, style=filled];
# "MAE 4580" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 2214" -> "MAE 4580";
# "MATH 2940" -> "MAE 4580";
# "MAE 4590" [fillcolor=white, fontcolor=black, style=filled];
# "PHYS 1112" -> "MAE 4590";
# "PHYS 2213" -> "MAE 4590";
# "PHYS 2214" -> "MAE 4590";
# "MAE 4610" [fillcolor=white, fontcolor=black, style=filled];
# "MAE 4660" [fillcolor=black, fontcolor=white, style=filled];
# "BIOG 1440" -> "MAE 4660";
# "ENGRD 2020" -> "MAE 4660";
# "BIOMG 1350" -> "MAE 4660";
# "BME 2010" -> "MAE 4660";
# "MAE 4670" [fillcolor=white, fontcolor=black, style=filled];
# "MAE 3270" -> "MAE 4670";
# "MSE 2610" -> "MAE 4670";
# "ENGRD 2020" -> "MAE 4670";
# "MAE 4671" [fillcolor=white, fontcolor=black, style=filled];
# "MAE 3270" -> "MAE 4671";
# "MSE 2610" -> "MAE 4671";
# "ENGRD 2020" -> "MAE 4671";
# "MAE 4700" [fillcolor=black, fontcolor=white, style=filled];
# "MAE 4701" [fillcolor=black, fontcolor=white, style=filled];
# "MAE 4300" -> "MAE 4701";
# "MAE 4721" [fillcolor=white, fontcolor=black, style=filled];
# "MAE 5700" -> "MAE 4721";
# "MAE 4700" -> "MAE 4721";
# "MAE 4701" -> "MAE 4721";
# "MAE 4730" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2940" -> "MAE 4730";
# "MAE 4760" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2940" -> "MAE 4760";
# "CS 1133" -> "MAE 4760";
# "CS 1110" -> "MAE 4760";
# "MATH 4710" -> "MAE 4760";
# "MATH 1920" -> "MAE 4760";
# "MATH 2210" -> "MAE 4760";
# "ENGRD 2700" -> "MAE 4760";
# "MAE 4770" [fillcolor=white, fontcolor=black, style=filled];
# "MAE 3260" -> "MAE 4770";
# "MAE 4780" [fillcolor=black, fontcolor=white, style=filled];
# "CHEME 3720" -> "MAE 4780";
# "MAE 3260" -> "MAE 4780";
# "MAE 4810" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2940" -> "MAE 4810";
# "ENGRD 2112" -> "MAE 4810";
# "MATH 4710" -> "MAE 4810";
# "ENGRD 2720" -> "MAE 4810";
# "ENGRD 2700" -> "MAE 4810";
# "MAE 4850" [fillcolor=white, fontcolor=black, style=filled];
# "MAE 4860" [fillcolor=white, fontcolor=black, style=filled];
# "MAE 2030" -> "MAE 4860";
# "ENGRD 2210" -> "MAE 4860";
# "MAE 4861" [fillcolor=white, fontcolor=black, style=filled];
# "MAE 4300" -> "MAE 4861";
# "MAE 2030" -> "MAE 4861";
# "ENGRD 2210" -> "MAE 4861";
# "MAE 4900" [fillcolor=gray, fontcolor=black, style=filled];
# "MAE 4950" [fillcolor=white, fontcolor=black, style=filled];
# "MAE 4980" [fillcolor=gray, fontcolor=black, style=filled];
# "MAE 4998" [fillcolor=gray, fontcolor=black, style=filled];
# "MAE 5700" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1106" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1106" -> "MATH 1120";
# "MATH 1110" -> "MATH 1120";
# "MATH 1910" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1910" -> "MATH 1920";
# "MATH 2130" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1120" -> "MATH 2130";
# "MATH 1910" -> "MATH 2130";
# "MATH 2210" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" -> "MATH 2210";
# "MATH 1110" -> "MATH 2210";
# "MATH 2220" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2210" -> "MATH 2220";
# "MATH 2230" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1120" -> "MATH 2230";
# "MATH 1110" -> "MATH 2230";
# "MATH 2240" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2230" -> "MATH 2240";
# "MATH 2310" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1106" -> "MATH 2310";
# "MATH 1110" -> "MATH 2310";
# "MATH 2930" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "MATH 2930";
# "MATH 2940" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "MATH 2940";
# "MATH 4710" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" -> "MATH 4710";
# "MATH 1110" -> "MATH 4710";
# "MSE 2060" [fillcolor=white, fontcolor=black, style=filled];
# "MSE 2610" -> "MSE 2060";
# "MSE 2610" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 1112" -> "MSE 2610";
# "MSE 3030" [fillcolor=black, fontcolor=white, style=filled];
# "MSE 2610" -> "MSE 3030";
# "MSE 3040" [fillcolor=white, fontcolor=black, style=filled];
# "MSE 3030" -> "MSE 3040";
# "PHYS 1101" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1112" -> "PHYS 1110";
# "PHYS 2213" -> "PHYS 1110";
# "PHYS 1116" -> "PHYS 1110";
# "PHYS 2217" -> "PHYS 1110";
# "PHYS 1112" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" -> "PHYS 1112";
# "PHYS 1110" -> "PHYS 1112";
# "PHYS 2213" -> "PHYS 1112";
# "PHYS 1112" -> "PHYS 1112";
# "MATH 1910" -> "PHYS 1112";
# "MATH 1920" -> "PHYS 1112";
# "PHYS 1116" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" -> "PHYS 1116";
# "PHYS 1116" -> "PHYS 1116";
# "PHYS 1110" -> "PHYS 1116";
# "MATH 1910" -> "PHYS 1116";
# "PHYS 2207" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1106" -> "PHYS 2207";
# "MATH 1110" -> "PHYS 2207";
# "PHYS 2208" [fillcolor=white, fontcolor=black, style=filled];
# "PHYS 1112" -> "PHYS 2208";
# "PHYS 1101" -> "PHYS 2208";
# "PHYS 2207" -> "PHYS 2208";
# "PHYS 2213" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2220" -> "PHYS 2213";
# "MATH 2240" -> "PHYS 2213";
# "PHYS 2207" -> "PHYS 2213";
# "PHYS 1112" -> "PHYS 2213";
# "MATH 1920" -> "PHYS 2213";
# "PHYS 2214" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2220" -> "PHYS 2214";
# "MATH 2130" -> "PHYS 2214";
# "MATH 2240" -> "PHYS 2214";
# "PHYS 2213" -> "PHYS 2214";
# "MATH 1920" -> "PHYS 2214";
# "PHYS 2208" -> "PHYS 2214";
# "PHYS 2217" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2220" -> "PHYS 2217";
# "PHYS 1116" -> "PHYS 2217";
# "MATH 2240" -> "PHYS 2217";
# "PHYS 1112" -> "PHYS 2217";
# "MATH 1920" -> "PHYS 2217";

# %%
course_list = get_course_list(['FA23', 'SP23'], 'MSE')
graph = PrerequisiteGraph(course_list)
graph.print_edges()
# Out:
# "CHEM 2090" [fillcolor=gray, fontcolor=black, style=filled];
# "ENGRC 3111" [fillcolor=black, fontcolor=white, style=filled];
# "MSE 3110" -> "ENGRC 3111";
# "ENGRD 2020" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1112" -> "ENGRD 2020";
# "MATH 1920" -> "ENGRD 2020";
# "ENGRD 2610" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 1112" -> "ENGRD 2610";
# "ENGRD 2620" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1920" -> "ENGRD 2620";
# "PHYS 2213" -> "ENGRD 2620";
# "MATH 1106" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1110" -> "MATH 1120";
# "MATH 1106" -> "MATH 1120";
# "MATH 1910" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1910" -> "MATH 1920";
# "MATH 2210" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" -> "MATH 2210";
# "MATH 1110" -> "MATH 2210";
# "MATH 2220" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2210" -> "MATH 2220";
# "MATH 2230" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1120" -> "MATH 2230";
# "MATH 1110" -> "MATH 2230";
# "MATH 2240" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2230" -> "MATH 2240";
# "MATH 2930" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "MATH 2930";
# "MATH 2940" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "MATH 2940";
# "MSE 1140" [fillcolor=black, fontcolor=white, style=filled];
# "MSE 1150" [fillcolor=white, fontcolor=black, style=filled];
# "MSE 1190" [fillcolor=black, fontcolor=white, style=filled];
# "MSE 1700" [fillcolor=white, fontcolor=black, style=filled];
# "MSE 2060" [fillcolor=white, fontcolor=black, style=filled];
# "MSE 2610" -> "MSE 2060";
# "MSE 2610" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 1112" -> "MSE 2610";
# "MSE 2620" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1920" -> "MSE 2620";
# "PHYS 2213" -> "MSE 2620";
# "MSE 2900" [fillcolor=gray, fontcolor=black, style=filled];
# "MSE 2910" [fillcolor=black, fontcolor=white, style=filled];
# "MSE 3010" [fillcolor=black, fontcolor=white, style=filled];
# "CHEM 2090" -> "MSE 3010";
# "MATH 2930" -> "MSE 3010";
# "ENGRD 2620" -> "MSE 3010";
# "MSE 3030" [fillcolor=black, fontcolor=white, style=filled];
# "MSE 2610" -> "MSE 3030";
# "MSE 3040" [fillcolor=white, fontcolor=black, style=filled];
# "MSE 3030" -> "MSE 3040";
# "MSE 3050" [fillcolor=white, fontcolor=black, style=filled];
# "MSE 3010" -> "MSE 3050";
# "MSE 2060" -> "MSE 3050";
# "MATH 2930" -> "MSE 3050";
# "MATH 2940" -> "MSE 3050";
# "PHYS 2213" -> "MSE 3050";
# "MSE 2620" -> "MSE 3050";
# "MSE 3070" [fillcolor=white, fontcolor=black, style=filled];
# "ENGRD 2610" -> "MSE 3070";
# "MSE 2060" -> "MSE 3070";
# "ENGRD 2620" -> "MSE 3070";
# "ENGRC 3111" -> "MSE 3070";
# "MSE 2610" -> "MSE 3070";
# "MSE 2620" -> "MSE 3070";
# "MSE 3110" [fillcolor=black, fontcolor=white, style=filled];
# "MSE 3010" -> "MSE 3110";
# "ENGRD 2610" -> "MSE 3110";
# "ENGRD 2620" -> "MSE 3110";
# "MSE 2610" -> "MSE 3110";
# "MSE 3030" -> "MSE 3110";
# "MSE 2620" -> "MSE 3110";
# "MSE 3120" [fillcolor=white, fontcolor=black, style=filled];
# "MSE 3110" -> "MSE 3120";
# "MSE 3050" -> "MSE 3120";
# "MSE 3040" -> "MSE 3120";
# "MSE 3900" [fillcolor=gray, fontcolor=black, style=filled];
# "MSE 3910" [fillcolor=black, fontcolor=white, style=filled];
# "MSE 4020" [fillcolor=black, fontcolor=white, style=filled];
# "MSE 2610" -> "MSE 4020";
# "MSE 4030" [fillcolor=black, fontcolor=white, style=filled];
# "MSE 3070" -> "MSE 4030";
# "MSE 3110" -> "MSE 4030";
# "MSE 3120" -> "MSE 4030";
# "MSE 4050" [fillcolor=black, fontcolor=white, style=filled];
# "MSE 4060" [fillcolor=white, fontcolor=black, style=filled];
# "MSE 4050" -> "MSE 4060";
# "MSE 4070" [fillcolor=white, fontcolor=black, style=filled];
# "MSE 3070" -> "MSE 4070";
# "MSE 4510" [fillcolor=black, fontcolor=white, style=filled];
# "ENGRD 2020" -> "MSE 4510";
# "ENGRD 2610" -> "MSE 4510";
# "MSE 4900" [fillcolor=gray, fontcolor=black, style=filled];
# "MSE 4910" [fillcolor=black, fontcolor=white, style=filled];
# "MSE 4950" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1112" -> "PHYS 1110";
# "PHYS 1116" -> "PHYS 1110";
# "PHYS 2213" -> "PHYS 1110";
# "PHYS 2217" -> "PHYS 1110";
# "PHYS 1112" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" -> "PHYS 1112";
# "PHYS 1110" -> "PHYS 1112";
# "PHYS 1112" -> "PHYS 1112";
# "MATH 1910" -> "PHYS 1112";
# "MATH 1920" -> "PHYS 1112";
# "PHYS 2213" -> "PHYS 1112";
# "PHYS 1116" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1910" -> "PHYS 1116";
# "PHYS 1116" -> "PHYS 1116";
# "PHYS 1110" -> "PHYS 1116";
# "MATH 1120" -> "PHYS 1116";
# "PHYS 2207" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1110" -> "PHYS 2207";
# "MATH 1106" -> "PHYS 2207";
# "PHYS 2213" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "PHYS 2213";
# "PHYS 1112" -> "PHYS 2213";
# "MATH 2240" -> "PHYS 2213";
# "MATH 2220" -> "PHYS 2213";
# "PHYS 2207" -> "PHYS 2213";
# "PHYS 2217" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1112" -> "PHYS 2217";
# "PHYS 1116" -> "PHYS 2217";
# "MATH 2240" -> "PHYS 2217";
# "MATH 2220" -> "PHYS 2217";
# "MATH 1920" -> "PHYS 2217";

# %%
course_list = get_course_list(['FA23', 'SP23'], 'ORIE')
graph = PrerequisiteGraph(course_list)
graph.print_edges()
# Out:
# "CS 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1112" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1110" -> "CS 1112";
# "MATH 1910" -> "CS 1112";
# "CS 2110" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1112" -> "CS 2110";
# "CS 1110" -> "CS 2110";
# "CS 2800" [fillcolor=gray, fontcolor=black, style=filled];
# "ENGRD 2110" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1110" -> "ENGRD 2110";
# "ENGRD 2700" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "ENGRD 2700";
# "MATH 1910" -> "ENGRD 2700";
# "MATH 1106" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1106" -> "MATH 1120";
# "MATH 1110" -> "MATH 1120";
# "MATH 1910" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1910" -> "MATH 1920";
# "MATH 2210" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1110" -> "MATH 2210";
# "MATH 1120" -> "MATH 2210";
# "MATH 2940" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "MATH 2940";
# "ORIE 1380" [fillcolor=white, fontcolor=black, style=filled];
# "ORIE 3120" [fillcolor=white, fontcolor=black, style=filled];
# "ENGRD 2700" -> "ORIE 3120";
# "ORIE 3150" [fillcolor=black, fontcolor=white, style=filled];
# "ORIE 3300" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2940" -> "ORIE 3300";
# "MATH 2210" -> "ORIE 3300";
# "ORIE 3310" [fillcolor=white, fontcolor=black, style=filled];
# "ORIE 3300" -> "ORIE 3310";
# "ORIE 3500" [fillcolor=black, fontcolor=white, style=filled];
# "ENGRD 2700" -> "ORIE 3500";
# "ORIE 3510" [fillcolor=white, fontcolor=black, style=filled];
# "ORIE 3500" -> "ORIE 3510";
# "ORIE 4100" [fillcolor=black, fontcolor=white, style=filled];
# "ORIE 4126" [fillcolor=white, fontcolor=black, style=filled];
# "ORIE 3510" -> "ORIE 4126";
# "ORIE 3310" -> "ORIE 4126";
# "ORIE 4130" [fillcolor=black, fontcolor=white, style=filled];
# "ORIE 3500" -> "ORIE 4130";
# "ORIE 3510" -> "ORIE 4130";
# "ORIE 4152" [fillcolor=white, fontcolor=black, style=filled];
# "ORIE 4154" [fillcolor=white, fontcolor=black, style=filled];
# "ORIE 3300" -> "ORIE 4154";
# "ORIE 3500" -> "ORIE 4154";
# "ORIE 4160" [fillcolor=white, fontcolor=black, style=filled];
# "ORIE 3500" -> "ORIE 4160";
# "ORIE 3120" -> "ORIE 4160";
# "ORIE 3510" -> "ORIE 4160";
# "ORIE 3310" -> "ORIE 4160";
# "ORIE 3300" -> "ORIE 4160";
# "ORIE 4330" [fillcolor=black, fontcolor=white, style=filled];
# "ORIE 3300" -> "ORIE 4330";
# "CS 2110" -> "ORIE 4330";
# "ORIE 4340" [fillcolor=gray, fontcolor=black, style=filled];
# "ORIE 3300" -> "ORIE 4340";
# "ORIE 3500" -> "ORIE 4340";
# "ORIE 4350" [fillcolor=gray, fontcolor=black, style=filled];
# "ORIE 3300" -> "ORIE 4350";
# "ORIE 4580" [fillcolor=black, fontcolor=white, style=filled];
# "ORIE 3500" -> "ORIE 4580";
# "ENGRD 2110" -> "ORIE 4580";
# "CS 2110" -> "ORIE 4580";
# "ORIE 4600" [fillcolor=white, fontcolor=black, style=filled];
# "ORIE 3500" -> "ORIE 4600";
# "ORIE 3510" -> "ORIE 4600";
# "ORIE 4630" [fillcolor=black, fontcolor=white, style=filled];
# "ORIE 3120" -> "ORIE 4630";
# "ENGRD 2700" -> "ORIE 4630";
# "ORIE 3500" -> "ORIE 4630";
# "MATH 2940" -> "ORIE 4630";
# "ORIE 4741" [fillcolor=gray, fontcolor=black, style=filled];
# "ENGRD 2700" -> "ORIE 4741";
# "ENGRD 2110" -> "ORIE 4741";
# "CS 2110" -> "ORIE 4741";
# "MATH 2940" -> "ORIE 4741";
# "CS 2800" -> "ORIE 4741";
# "ORIE 4820" [fillcolor=white, fontcolor=black, style=filled];
# "ENGRD 2700" -> "ORIE 4820";
# "ORIE 3300" -> "ORIE 4820";
# "ORIE 4990" [fillcolor=gray, fontcolor=black, style=filled];
# "ORIE 4999" [fillcolor=gray, fontcolor=black, style=filled];

# %%
course_list = get_course_list(['FA23', 'SP23'], 'EAS')
graph = PrerequisiteGraph(course_list)
graph.print_edges()
# Out:
# Class not found: BIOSM 1780
# Class not found: BIOSM 1780
# "BIOEE 1540" [fillcolor=black, fontcolor=white, style=filled];
# "BIOEE 1560" [fillcolor=black, fontcolor=white, style=filled];
# "BIOEE 1610" [fillcolor=gray, fontcolor=black, style=filled];
# "BIOEE 1780" [fillcolor=gray, fontcolor=black, style=filled];
# "BIOSM 1780" [fillcolor=white, fontcolor=black, style=filled];
# "CHEM 2070" [fillcolor=gray, fontcolor=black, style=filled];
# "EAS 1101" [fillcolor=black, fontcolor=white, style=filled];
# "EAS 1180" [fillcolor=gray, fontcolor=black, style=filled];
# "EAS 1220" [fillcolor=black, fontcolor=white, style=filled];
# "EAS 1310" [fillcolor=black, fontcolor=white, style=filled];
# "EAS 1330" [fillcolor=black, fontcolor=white, style=filled];
# "EAS 1310" -> "EAS 1330";
# "EAS 1340" [fillcolor=white, fontcolor=black, style=filled];
# "EAS 1310" -> "EAS 1340";
# "EAS 1330" -> "EAS 1340";
# "EAS 1540" [fillcolor=black, fontcolor=white, style=filled];
# "EAS 1560" [fillcolor=black, fontcolor=white, style=filled];
# "EAS 1600" [fillcolor=gray, fontcolor=black, style=filled];
# "EAS 1700" [fillcolor=white, fontcolor=black, style=filled];
# "EAS 2250" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1910" -> "EAS 2250";
# "MATH 1110" -> "EAS 2250";
# "EAS 2500" [fillcolor=white, fontcolor=black, style=filled];
# "EAS 1310" -> "EAS 2500";
# "EAS 2680" [fillcolor=white, fontcolor=black, style=filled];
# "EAS 2900" [fillcolor=black, fontcolor=white, style=filled];
# "EAS 1310" -> "EAS 2900";
# "MATH 1110" -> "EAS 2900";
# "EAS 3010" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1110" -> "EAS 3010";
# "EAS 2250" -> "EAS 3010";
# "MATH 1910" -> "EAS 3010";
# "EAS 3030" [fillcolor=black, fontcolor=white, style=filled];
# "CHEM 2070" -> "EAS 3030";
# "MATH 1120" -> "EAS 3030";
# "EAS 3050" [fillcolor=black, fontcolor=white, style=filled];
# "EAS 3090" [fillcolor=white, fontcolor=black, style=filled];
# "EAS 2250" -> "EAS 3090";
# "CHEM 2070" -> "EAS 3090";
# "EAS 3340" [fillcolor=black, fontcolor=white, style=filled];
# "EAS 1310" -> "EAS 3340";
# "EAS 2500" -> "EAS 3340";
# "EAS 3410" [fillcolor=black, fontcolor=white, style=filled];
# "EAS 3420" [fillcolor=white, fontcolor=black, style=filled];
# "EAS 3520" [fillcolor=white, fontcolor=black, style=filled];
# "EAS 3420" -> "EAS 3520";
# "EAS 3410" -> "EAS 3520";
# "EAS 3530" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1920" -> "EAS 3530";
# "EAS 1540" -> "EAS 3530";
# "PHYS 1112" -> "EAS 3530";
# "BIOEE 1540" -> "EAS 3530";
# "BIOEE 1560" -> "EAS 3530";
# "EAS 1560" -> "EAS 3530";
# "PHYS 2207" -> "EAS 3530";
# "MATH 1120" -> "EAS 3530";
# "EAS 3555" [fillcolor=white, fontcolor=black, style=filled];
# "EAS 1540" -> "EAS 3555";
# "BIOEE 1610" -> "EAS 3555";
# "BIOEE 1780" -> "EAS 3555";
# "BIOEE 1540" -> "EAS 3555";
# "EAS 3880" [fillcolor=white, fontcolor=black, style=filled];
# "PHYS 2208" -> "EAS 3880";
# "PHYS 2213" -> "EAS 3880";
# "MATH 1120" -> "EAS 3880";
# "MATH 1920" -> "EAS 3880";
# "EAS 4010" [fillcolor=black, fontcolor=white, style=filled];
# "EAS 4040" [fillcolor=black, fontcolor=white, style=filled];
# "EAS 4150" [fillcolor=white, fontcolor=black, style=filled];
# "EAS 4190" [fillcolor=black, fontcolor=white, style=filled];
# "EAS 4370" [fillcolor=white, fontcolor=black, style=filled];
# "PHYS 2208" -> "EAS 4370";
# "PHYS 2213" -> "EAS 4370";
# "MATH 1920" -> "EAS 4370";
# "EAS 4444" [fillcolor=white, fontcolor=black, style=filled];
# "EAS 4470" [fillcolor=black, fontcolor=white, style=filled];
# "EAS 4510" [fillcolor=black, fontcolor=white, style=filled];
# "EAS 3420" -> "EAS 4510";
# "EAS 3410" -> "EAS 4510";
# "EAS 4561" [fillcolor=white, fontcolor=black, style=filled];
# "EAS 4570" [fillcolor=white, fontcolor=black, style=filled];
# "EAS 3410" -> "EAS 4570";
# "EAS 4700" [fillcolor=white, fontcolor=black, style=filled];
# "EAS 3520" -> "EAS 4700";
# "EAS 4510" -> "EAS 4700";
# "EAS 4710" [fillcolor=white, fontcolor=black, style=filled];
# "EAS 4790" [fillcolor=white, fontcolor=black, style=filled];
# "BIOSM 1780" -> "EAS 4790";
# "BIOEE 1780" -> "EAS 4790";
# "EAS 3010" -> "EAS 4790";
# "EAS 4795" [fillcolor=black, fontcolor=white, style=filled];
# "EAS 4860" [fillcolor=white, fontcolor=black, style=filled];
# "EAS 3420" -> "EAS 4860";
# "EAS 3410" -> "EAS 4860";
# "EAS 3050" -> "EAS 4860";
# "EAS 4910" [fillcolor=black, fontcolor=white, style=filled];
# "EAS 4920" [fillcolor=white, fontcolor=black, style=filled];
# "EAS 4940" [fillcolor=white, fontcolor=black, style=filled];
# "EAS 4960" [fillcolor=gray, fontcolor=black, style=filled];
# "EAS 4970" [fillcolor=gray, fontcolor=black, style=filled];
# "EAS 4980" [fillcolor=gray, fontcolor=black, style=filled];
# "EAS 4990" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1106" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1106" -> "MATH 1120";
# "MATH 1110" -> "MATH 1120";
# "MATH 1910" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1910" -> "MATH 1920";
# "MATH 2210" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1110" -> "MATH 2210";
# "MATH 1120" -> "MATH 2210";
# "MATH 2220" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 2210" -> "MATH 2220";
# "MATH 2230" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1110" -> "MATH 2230";
# "MATH 1120" -> "MATH 2230";
# "MATH 2240" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2230" -> "MATH 2240";
# "PHYS 1101" [fillcolor=black, fontcolor=white, style=filled];
# "PHYS 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1116" -> "PHYS 1110";
# "PHYS 2213" -> "PHYS 1110";
# "PHYS 1112" -> "PHYS 1110";
# "PHYS 2217" -> "PHYS 1110";
# "PHYS 1112" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 2213" -> "PHYS 1112";
# "MATH 1920" -> "PHYS 1112";
# "PHYS 1110" -> "PHYS 1112";
# "PHYS 1112" -> "PHYS 1112";
# "MATH 1910" -> "PHYS 1112";
# "MATH 1120" -> "PHYS 1112";
# "PHYS 1116" [fillcolor=gray, fontcolor=black, style=filled];
# "PHYS 1116" -> "PHYS 1116";
# "PHYS 1110" -> "PHYS 1116";
# "MATH 1910" -> "PHYS 1116";
# "MATH 1120" -> "PHYS 1116";
# "PHYS 2207" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 1106" -> "PHYS 2207";
# "MATH 1110" -> "PHYS 2207";
# "PHYS 2208" [fillcolor=white, fontcolor=black, style=filled];
# "PHYS 1101" -> "PHYS 2208";
# "PHYS 2207" -> "PHYS 2208";
# "PHYS 1112" -> "PHYS 2208";
# "PHYS 2213" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "PHYS 2213";
# "PHYS 1112" -> "PHYS 2213";
# "PHYS 2207" -> "PHYS 2213";
# "MATH 2220" -> "PHYS 2213";
# "MATH 2240" -> "PHYS 2213";
# "PHYS 2217" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "PHYS 2217";
# "PHYS 1112" -> "PHYS 2217";
# "PHYS 1116" -> "PHYS 2217";
# "MATH 2220" -> "PHYS 2217";
# "MATH 2240" -> "PHYS 2217";

# %%
course_list = get_course_list(['FA23', 'SP23'], 'INFO')
graph = PrerequisiteGraph(course_list)
graph.print_edges()
# Out:
# "COMM 2450" [fillcolor=gray, fontcolor=black, style=filled];
# "COMM 3450" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1112" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1910" -> "CS 1112";
# "MATH 1110" -> "CS 1112";
# "CS 1340" [fillcolor=white, fontcolor=black, style=filled];
# "CS 2024" [fillcolor=black, fontcolor=white, style=filled];
# "CS 2110" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1110" -> "CS 2110";
# "CS 1112" -> "CS 2110";
# "CS 2800" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 3152" [fillcolor=white, fontcolor=black, style=filled];
# "ENGRC 3152" -> "CS 3152";
# "CS 3300" [fillcolor=black, fontcolor=white, style=filled];
# "CS 2110" -> "CS 3300";
# "ENGRD 2110" -> "CS 3300";
# "CS 3410" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 2024" -> "CS 3410";
# "CS 2110" -> "CS 3410";
# "CS 3420" [fillcolor=white, fontcolor=black, style=filled];
# "ENGRD 2140" -> "CS 3420";
# "ECE 2400" -> "CS 3420";
# "ECE 2300" -> "CS 3420";
# "ENGRD 2300" -> "CS 3420";
# "CS 4152" [fillcolor=white, fontcolor=black, style=filled];
# "ENGRC 4152" -> "CS 4152";
# "CS 3152" -> "CS 4152";
# "CS 4620" -> "CS 4152";
# "CS 3300" -> "CS 4152";
# "CS 5414" -> "CS 4152";
# "CS 4700" -> "CS 4152";
# "CS 4300" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2940" -> "CS 4300";
# "CS 2800" -> "CS 4300";
# "CS 4410" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 3410" -> "CS 4410";
# "CS 3420" -> "CS 4410";
# "CS 4620" [fillcolor=black, fontcolor=white, style=filled];
# "MATH 2940" -> "CS 4620";
# "CS 2110" -> "CS 4620";
# "MATH 2210" -> "CS 4620";
# "ENGRD 2110" -> "CS 4620";
# "CS 4700" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 2110" -> "CS 4700";
# "CS 2800" -> "CS 4700";
# "ENGRD 2110" -> "CS 4700";
# "CS 5414" [fillcolor=white, fontcolor=black, style=filled];
# "CS 4410" -> "CS 5414";
# "ECE 2300" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1110" -> "ECE 2300";
# "CS 1112" -> "ECE 2300";
# "ECE 2400" [fillcolor=black, fontcolor=white, style=filled];
# "CS 1110" -> "ECE 2400";
# "CS 1112" -> "ECE 2400";
# "ECON 3110" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1110" -> "ECON 3110";
# "ENGRC 3152" [fillcolor=white, fontcolor=black, style=filled];
# "CS 3152" -> "ENGRC 3152";
# "INFO 3152" -> "ENGRC 3152";
# "ENGRC 4152" [fillcolor=white, fontcolor=black, style=filled];
# "INFO 4152" -> "ENGRC 4152";
# "CS 4152" -> "ENGRC 4152";
# "ENGRD 2110" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1110" -> "ENGRD 2110";
# "ENGRD 2140" [fillcolor=black, fontcolor=white, style=filled];
# "CS 1110" -> "ENGRD 2140";
# "CS 1112" -> "ENGRD 2140";
# "ENGRD 2300" [fillcolor=gray, fontcolor=black, style=filled];
# "CS 1110" -> "ENGRD 2300";
# "CS 1112" -> "ENGRD 2300";
# "INFO 1200" [fillcolor=black, fontcolor=white, style=filled];
# "INFO 1260" [fillcolor=white, fontcolor=black, style=filled];
# "INFO 1300" [fillcolor=gray, fontcolor=black, style=filled];
# "INFO 1380" [fillcolor=white, fontcolor=black, style=filled];
# "INFO 1998" [fillcolor=gray, fontcolor=black, style=filled];
# "INFO 2040" [fillcolor=black, fontcolor=white, style=filled];
# "INFO 2300" [fillcolor=white, fontcolor=black, style=filled];
# "INFO 1300" -> "INFO 2300";
# "INFO 2310" [fillcolor=black, fontcolor=white, style=filled];
# "INFO 2450" [fillcolor=gray, fontcolor=black, style=filled];
# "INFO 2770" [fillcolor=white, fontcolor=black, style=filled];
# "INFO 2921" [fillcolor=white, fontcolor=black, style=filled];
# "INFO 2950" [fillcolor=black, fontcolor=white, style=filled];
# "CS 1110" -> "INFO 2950";
# "CS 1112" -> "INFO 2950";
# "MATH 1710" -> "INFO 2950";
# "INFO 3140" [fillcolor=white, fontcolor=black, style=filled];
# "INFO 3152" [fillcolor=white, fontcolor=black, style=filled];
# "ENGRC 3152" -> "INFO 3152";
# "INFO 3200" [fillcolor=white, fontcolor=black, style=filled];
# "INFO 3300" [fillcolor=black, fontcolor=white, style=filled];
# "CS 2110" -> "INFO 3300";
# "ENGRD 2110" -> "INFO 3300";
# "INFO 3312" [fillcolor=white, fontcolor=black, style=filled];
# "INFO 2950" -> "INFO 3312";
# "INFO 3350" [fillcolor=black, fontcolor=white, style=filled];
# "INFO 3370" [fillcolor=white, fontcolor=black, style=filled];
# "INFO 2950" -> "INFO 3370";
# "INFO 3450" [fillcolor=gray, fontcolor=black, style=filled];
# "INFO 3900" [fillcolor=black, fontcolor=white, style=filled];
# "ECON 3110" -> "INFO 3900";
# "PSYCH 2500" -> "INFO 3900";
# "STSCI 2110" -> "INFO 3900";
# "SOC 3010" -> "INFO 3900";
# "INFO 3950" [fillcolor=white, fontcolor=black, style=filled];
# "INFO 2950" -> "INFO 3950";
# "INFO 4125" [fillcolor=black, fontcolor=white, style=filled];
# "INFO 4152" [fillcolor=white, fontcolor=black, style=filled];
# "ENGRC 4152" -> "INFO 4152";
# "INFO 4210" [fillcolor=white, fontcolor=black, style=filled];
# "INFO 4220" [fillcolor=white, fontcolor=black, style=filled];
# "CS 2800" -> "INFO 4220";
# "INFO 2040" -> "INFO 4220";
# "INFO 4240" [fillcolor=black, fontcolor=white, style=filled];
# "INFO 4250" [fillcolor=black, fontcolor=white, style=filled];
# "INFO 1200" -> "INFO 4250";
# "INFO 4260" [fillcolor=white, fontcolor=black, style=filled];
# "CS 1340" -> "INFO 4260";
# "INFO 1260" -> "INFO 4260";
# "INFO 1200" -> "INFO 4260";
# "INFO 4300" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 2940" -> "INFO 4300";
# "CS 2800" -> "INFO 4300";
# "INFO 4301" [fillcolor=black, fontcolor=white, style=filled];
# "INFO 4310" [fillcolor=white, fontcolor=black, style=filled];
# "CS 3300" -> "INFO 4310";
# "INFO 3300" -> "INFO 4310";
# "INFO 5100" -> "INFO 4310";
# "INFO 4320" [fillcolor=gray, fontcolor=black, style=filled];
# "INFO 2300" -> "INFO 4320";
# "INFO 4340" [fillcolor=gray, fontcolor=black, style=filled];
# "INFO 4350" [fillcolor=black, fontcolor=white, style=filled];
# "CS 4300" -> "INFO 4350";
# "MATH 2940" -> "INFO 4350";
# "CS 2800" -> "INFO 4350";
# "INFO 4300" -> "INFO 4350";
# "CS 2110" -> "INFO 4350";
# "INFO 4360" [fillcolor=gray, fontcolor=black, style=filled];
# "INFO 2450" -> "INFO 4360";
# "COMM 2450" -> "INFO 4360";
# "INFO 2040" -> "INFO 4360";
# "INFO 4400" [fillcolor=white, fontcolor=black, style=filled];
# "INFO 5355" -> "INFO 4400";
# "INFO 3450" -> "INFO 4400";
# "COMM 3450" -> "INFO 4400";
# "INFO 4420" [fillcolor=black, fontcolor=white, style=filled];
# "INFO 3450" -> "INFO 4420";
# "INFO 4430" [fillcolor=black, fontcolor=white, style=filled];
# "INFO 4450" [fillcolor=white, fontcolor=black, style=filled];
# "INFO 2450" -> "INFO 4450";
# "COMM 2450" -> "INFO 4450";
# "INFO 4500" [fillcolor=black, fontcolor=white, style=filled];
# "INFO 2450" -> "INFO 4500";
# "COMM 2450" -> "INFO 4500";
# "INFO 4555" [fillcolor=black, fontcolor=white, style=filled];
# "INFO 4561" [fillcolor=white, fontcolor=black, style=filled];
# "INFO 4900" [fillcolor=gray, fontcolor=black, style=filled];
# "INFO 4910" [fillcolor=gray, fontcolor=black, style=filled];
# "INFO 4940" [fillcolor=gray, fontcolor=black, style=filled];
# "INFO 4997" [fillcolor=gray, fontcolor=black, style=filled];
# "INFO 4998" [fillcolor=gray, fontcolor=black, style=filled];
# "INFO 5100" [fillcolor=black, fontcolor=white, style=filled];
# "INFO 5355" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1106" [fillcolor=white, fontcolor=black, style=filled];
# "MATH 1110" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1106" -> "MATH 1120";
# "MATH 1110" -> "MATH 1120";
# "MATH 1710" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1910" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1910" -> "MATH 1920";
# "MATH 2210" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1120" -> "MATH 2210";
# "MATH 1110" -> "MATH 2210";
# "MATH 2940" [fillcolor=gray, fontcolor=black, style=filled];
# "MATH 1920" -> "MATH 2940";
# "PSYCH 2500" [fillcolor=black, fontcolor=white, style=filled];
# "SOC 3010" [fillcolor=black, fontcolor=white, style=filled];
# "STSCI 2100" [fillcolor=gray, fontcolor=black, style=filled];
# "STSCI 2110" [fillcolor=white, fontcolor=black, style=filled];
# "STSCI 2100" -> "STSCI 2110";
